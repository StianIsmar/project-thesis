# %% [markdown]
# # Filling in blanks

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
import matplotlib.pyplot as plt

SMALL_SIZE = 8
MEDIUM_SIZE = 10
BIGGER_SIZE = 12

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
def count(dataframe):
    print(np.logical_not(dataframe.isnull()).sum()[0])

# %% [markdown]
# ### Load SCADA operational data

# %%
def load_data(path):
    df = pd.read_csv(path,sep = ';')
    return df

# %%
# Loop through all csv files in folder and add them to list:
path = './DataFromBazefield/scada_data_bessaker/'
allFiles = glob.glob(path + "/*.csv")

list_of_wt_scada_data = []
for file_ in allFiles:
    df = load_data(file_)
    list_of_wt_scada_data.append(df)

list_of_wt_scada_data[0]
# Out:
#                    TimeStamp  BESS-WTG01-WindVane (Average)  \
# 0        15-07-2017 00:00:00                            NaN
# 1        15-07-2017 00:00:30                            NaN
# 2        15-07-2017 00:01:00                            NaN
# 3        15-07-2017 00:01:30                            NaN
# 4        15-07-2017 00:02:00                            NaN
# 5        15-07-2017 00:02:30                            NaN
# 6        15-07-2017 00:03:00                            NaN
# 7        15-07-2017 00:03:30                            NaN
# 8        15-07-2017 00:04:00                            NaN
# 9        15-07-2017 00:04:30                            NaN
# 10       15-07-2017 00:05:00                            NaN
# 11       15-07-2017 00:05:30                            NaN
# 12       15-07-2017 00:06:00                            NaN
# 13       15-07-2017 00:06:30                            NaN
# 14       15-07-2017 00:07:00                            NaN
# 15       15-07-2017 00:07:30                            NaN
# 16       15-07-2017 00:08:00                            NaN
# 17       15-07-2017 00:08:30                            NaN
# 18       15-07-2017 00:09:00                            NaN
# 19       15-07-2017 00:09:30                            NaN
# 20       15-07-2017 00:10:00                            NaN
# 21       15-07-2017 00:10:30                            NaN
# 22       15-07-2017 00:11:00                            NaN
# 23       15-07-2017 00:11:30                            NaN
# 24       15-07-2017 00:12:00                            NaN
# 25       15-07-2017 00:12:30                            NaN
# 26       15-07-2017 00:13:00                            NaN
# 27       15-07-2017 00:13:30                            NaN
# 28       15-07-2017 00:14:00                            NaN
# 29       15-07-2017 00:14:30                            NaN
# ...                      ...                            ...
# 2373090  16-10-2019 23:45:00                            NaN
# 2373091  16-10-2019 23:45:30                            NaN
# 2373092  16-10-2019 23:46:00                            NaN
# 2373093  16-10-2019 23:46:30                            NaN
# 2373094  16-10-2019 23:47:00                            NaN
# 2373095  16-10-2019 23:47:30                            NaN
# 2373096  16-10-2019 23:48:00                            NaN
# 2373097  16-10-2019 23:48:30                            NaN
# 2373098  16-10-2019 23:49:00                            NaN
# 2373099  16-10-2019 23:49:30                            NaN
# 2373100  16-10-2019 23:50:00                            NaN
# 2373101  16-10-2019 23:50:30                            NaN
# 2373102  16-10-2019 23:51:00                            NaN
# 2373103  16-10-2019 23:51:30                            NaN
# 2373104  16-10-2019 23:52:00                            NaN
# 2373105  16-10-2019 23:52:30                            NaN
# 2373106  16-10-2019 23:53:00                            NaN
# 2373107  16-10-2019 23:53:30                            NaN
# 2373108  16-10-2019 23:54:00                            NaN
# 2373109  16-10-2019 23:54:30                            NaN
# 2373110  16-10-2019 23:55:00                            NaN
# 2373111  16-10-2019 23:55:30                            NaN
# 2373112  16-10-2019 23:56:00                            NaN
# 2373113  16-10-2019 23:56:30                            NaN
# 2373114  16-10-2019 23:57:00                            NaN
# 2373115  16-10-2019 23:57:30                            NaN
# 2373116  16-10-2019 23:58:00                            NaN
# 2373117  16-10-2019 23:58:30                            NaN
# 2373118  16-10-2019 23:59:00                            NaN
# 2373119  16-10-2019 23:59:30                            NaN
#
#          BESS-WTG01-WindSpeed (Average)  BESS-WTG01-RotorSpeed (Average)  \
# 0                                   4.5                             9.75
# 1                                   NaN                              NaN
# 2                                   NaN                              NaN
# 3                                   NaN                              NaN
# 4                                   NaN                              NaN
# 5                                   NaN                              NaN
# 6                                   NaN                              NaN
# 7                                   NaN                              NaN
# 8                                   NaN                              NaN
# 9                                   NaN                              NaN
# 10                                  NaN                              NaN
# 11                                  NaN                              NaN
# 12                                  NaN                              NaN
# 13                                  NaN                              NaN
# 14                                  NaN                              NaN
# 15                                  NaN                              NaN
# 16                                  NaN                              NaN
# 17                                  NaN                              NaN
# 18                                  NaN                              NaN
# 19                                  NaN                              NaN
# 20                                  4.6                             9.90
# 21                                  NaN                              NaN
# 22                                  NaN                              NaN
# 23                                  NaN                              NaN
# 24                                  NaN                              NaN
# 25                                  NaN                              NaN
# 26                                  NaN                              NaN
# 27                                  NaN                              NaN
# 28                                  NaN                              NaN
# 29                                  NaN                              NaN
# ...                                 ...                              ...
# 2373090                             NaN                              NaN
# 2373091                             NaN                              NaN
# 2373092                             NaN                              NaN
# 2373093                             NaN                              NaN
# 2373094                             NaN                              NaN
# 2373095                             NaN                              NaN
# 2373096                             NaN                              NaN
# 2373097                             NaN                              NaN
# 2373098                             NaN                              NaN
# 2373099                             NaN                              NaN
# 2373100                             NaN                              NaN
# 2373101                             NaN                              NaN
# 2373102                             NaN                              NaN
# 2373103                             NaN                              NaN
# 2373104                             NaN                              NaN
# 2373105                             NaN                              NaN
# 2373106                             NaN                              NaN
# 2373107                             NaN                              NaN
# 2373108                             NaN                              NaN
# 2373109                             NaN                              NaN
# 2373110                             NaN                              NaN
# 2373111                             NaN                              NaN
# 2373112                             NaN                              NaN
# 2373113                             NaN                              NaN
# 2373114                             NaN                              NaN
# 2373115                             NaN                              NaN
# 2373116                             NaN                              NaN
# 2373117                             NaN                              NaN
# 2373118                             NaN                              NaN
# 2373119                             NaN                              NaN
#
#          BESS-WTG01-NacelleDirection (Average)  \
# 0                                        227.0
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# 5                                          NaN
# 6                                          NaN
# 7                                          NaN
# 8                                          NaN
# 9                                          NaN
# 10                                         NaN
# 11                                         NaN
# 12                                         NaN
# 13                                         NaN
# 14                                         NaN
# 15                                         NaN
# 16                                         NaN
# 17                                         NaN
# 18                                         NaN
# 19                                         NaN
# 20                                       225.0
# 21                                         NaN
# 22                                         NaN
# 23                                         NaN
# 24                                         NaN
# 25                                         NaN
# 26                                         NaN
# 27                                         NaN
# 28                                         NaN
# 29                                         NaN
# ...                                        ...
# 2373090                                    NaN
# 2373091                                    NaN
# 2373092                                    NaN
# 2373093                                    NaN
# 2373094                                    NaN
# 2373095                                    NaN
# 2373096                                    NaN
# 2373097                                    NaN
# 2373098                                    NaN
# 2373099                                    NaN
# 2373100                                    NaN
# 2373101                                    NaN
# 2373102                                    NaN
# 2373103                                    NaN
# 2373104                                    NaN
# 2373105                                    NaN
# 2373106                                    NaN
# 2373107                                    NaN
# 2373108                                    NaN
# 2373109                                    NaN
# 2373110                                    NaN
# 2373111                                    NaN
# 2373112                                    NaN
# 2373113                                    NaN
# 2373114                                    NaN
# 2373115                                    NaN
# 2373116                                    NaN
# 2373117                                    NaN
# 2373118                                    NaN
# 2373119                                    NaN
#
#          BESS-WTG01-ActivePower (Average)  \
# 0                                   109.0
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                  117.0
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    NaN
# 26                                    NaN
# 27                                    NaN
# 28                                    NaN
# 29                                    NaN
# ...                                   ...
# 2373090                               NaN
# 2373091                               NaN
# 2373092                               NaN
# 2373093                               NaN
# 2373094                               NaN
# 2373095                               NaN
# 2373096                               NaN
# 2373097                               NaN
# 2373098                               NaN
# 2373099                               NaN
# 2373100                               NaN
# 2373101                               NaN
# 2373102                               NaN
# 2373103                               NaN
# 2373104                               NaN
# 2373105                               NaN
# 2373106                               NaN
# 2373107                               NaN
# 2373108                               NaN
# 2373109                               NaN
# 2373110                               NaN
# 2373111                               NaN
# 2373112                               NaN
# 2373113                               NaN
# 2373114                               NaN
# 2373115                               NaN
# 2373116                               NaN
# 2373117                               NaN
# 2373118                               NaN
# 2373119                               NaN
#
#          BESS-WTG01-Spinner-Temperature (Average)  \
# 0                                            24.0
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                           24.0
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25                                            NaN
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
# ...                                           ...
# 2373090                                       NaN
# 2373091                                       NaN
# 2373092                                       NaN
# 2373093                                       NaN
# 2373094                                       NaN
# 2373095                                       NaN
# 2373096                                       NaN
# 2373097                                       NaN
# 2373098                                       NaN
# 2373099                                       NaN
# 2373100                                       NaN
# 2373101                                       NaN
# 2373102                                       NaN
# 2373103                                       NaN
# 2373104                                       NaN
# 2373105                                       NaN
# 2373106                                       NaN
# 2373107                                       NaN
# 2373108                                       NaN
# 2373109                                       NaN
# 2373110                                       NaN
# 2373111                                       NaN
# 2373112                                       NaN
# 2373113                                       NaN
# 2373114                                       NaN
# 2373115                                       NaN
# 2373116                                       NaN
# 2373117                                       NaN
# 2373118                                       NaN
# 2373119                                       NaN
#
#          BESS-WTG01-Log-T-Raw-FrontBearingTemperature (Average)  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
# 10                                                     NaN
# 11                                                     NaN
# 12                                                     NaN
# 13                                                     NaN
# 14                                                     NaN
# 15                                                     NaN
# 16                                                     NaN
# 17                                                     NaN
# 18                                                     NaN
# 19                                                     NaN
# 20                                                     NaN
# 21                                                     NaN
# 22                                                     NaN
# 23                                                     NaN
# 24                                                     NaN
# 25                                                     NaN
# 26                                                     NaN
# 27                                                     NaN
# 28                                                     NaN
# 29                                                     NaN
# ...                                                    ...
# 2373090                                                NaN
# 2373091                                                NaN
# 2373092                                                NaN
# 2373093                                                NaN
# 2373094                                                NaN
# 2373095                                                NaN
# 2373096                                                NaN
# 2373097                                                NaN
# 2373098                                                NaN
# 2373099                                                NaN
# 2373100                                                NaN
# 2373101                                                NaN
# 2373102                                                NaN
# 2373103                                                NaN
# 2373104                                                NaN
# 2373105                                                NaN
# 2373106                                                NaN
# 2373107                                                NaN
# 2373108                                                NaN
# 2373109                                                NaN
# 2373110                                                NaN
# 2373111                                                NaN
# 2373112                                                NaN
# 2373113                                                NaN
# 2373114                                                NaN
# 2373115                                                NaN
# 2373116                                                NaN
# 2373117                                                NaN
# 2373118                                                NaN
# 2373119                                                NaN
#
#          BESS-WTG01-Log-T-Raw-RearBearingTemperature (Average)  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
# 10                                                     NaN
# 11                                                     NaN
# 12                                                     NaN
# 13                                                     NaN
# 14                                                     NaN
# 15                                                     NaN
# 16                                                     NaN
# 17                                                     NaN
# 18                                                     NaN
# 19                                                     NaN
# 20                                                     NaN
# 21                                                     NaN
# 22                                                     NaN
# 23                                                     NaN
# 24                                                     NaN
# 25                                                     NaN
# 26                                                     NaN
# 27                                                     NaN
# 28                                                     NaN
# 29                                                     NaN
# ...                                                    ...
# 2373090                                                NaN
# 2373091                                                NaN
# 2373092                                                NaN
# 2373093                                                NaN
# 2373094                                                NaN
# 2373095                                                NaN
# 2373096                                                NaN
# 2373097                                                NaN
# 2373098                                                NaN
# 2373099                                                NaN
# 2373100                                                NaN
# 2373101                                                NaN
# 2373102                                                NaN
# 2373103                                                NaN
# 2373104                                                NaN
# 2373105                                                NaN
# 2373106                                                NaN
# 2373107                                                NaN
# 2373108                                                NaN
# 2373109                                                NaN
# 2373110                                                NaN
# 2373111                                                NaN
# 2373112                                                NaN
# 2373113                                                NaN
# 2373114                                                NaN
# 2373115                                                NaN
# 2373116                                                NaN
# 2373117                                                NaN
# 2373118                                                NaN
# 2373119                                                NaN
#
#          BESS-WTG01-Log-T-Raw-BladeAPitchHeatSink (Average)  ...  \
# 0                                                      NaN   ...
# 1                                                      NaN   ...
# 2                                                      NaN   ...
# 3                                                      NaN   ...
# 4                                                      NaN   ...
# 5                                                      NaN   ...
# 6                                                      NaN   ...
# 7                                                      NaN   ...
# 8                                                      NaN   ...
# 9                                                      NaN   ...
# 10                                                     NaN   ...
# 11                                                     NaN   ...
# 12                                                     NaN   ...
# 13                                                     NaN   ...
# 14                                                     NaN   ...
# 15                                                     NaN   ...
# 16                                                     NaN   ...
# 17                                                     NaN   ...
# 18                                                     NaN   ...
# 19                                                     NaN   ...
# 20                                                     NaN   ...
# 21                                                     NaN   ...
# 22                                                     NaN   ...
# 23                                                     NaN   ...
# 24                                                     NaN   ...
# 25                                                     NaN   ...
# 26                                                     NaN   ...
# 27                                                     NaN   ...
# 28                                                     NaN   ...
# 29                                                     NaN   ...
# ...                                                    ...   ...
# 2373090                                                NaN   ...
# 2373091                                                NaN   ...
# 2373092                                                NaN   ...
# 2373093                                                NaN   ...
# 2373094                                                NaN   ...
# 2373095                                                NaN   ...
# 2373096                                                NaN   ...
# 2373097                                                NaN   ...
# 2373098                                                NaN   ...
# 2373099                                                NaN   ...
# 2373100                                                NaN   ...
# 2373101                                                NaN   ...
# 2373102                                                NaN   ...
# 2373103                                                NaN   ...
# 2373104                                                NaN   ...
# 2373105                                                NaN   ...
# 2373106                                                NaN   ...
# 2373107                                                NaN   ...
# 2373108                                                NaN   ...
# 2373109                                                NaN   ...
# 2373110                                                NaN   ...
# 2373111                                                NaN   ...
# 2373112                                                NaN   ...
# 2373113                                                NaN   ...
# 2373114                                                NaN   ...
# 2373115                                                NaN   ...
# 2373116                                                NaN   ...
# 2373117                                                NaN   ...
# 2373118                                                NaN   ...
# 2373119                                                NaN   ...
#
#          BESS-WTG01-Log-T-Raw-Rectifier1HeatSink (Average)  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
# 10                                                     NaN
# 11                                                     NaN
# 12                                                     NaN
# 13                                                     NaN
# 14                                                     NaN
# 15                                                     NaN
# 16                                                     NaN
# 17                                                     NaN
# 18                                                     NaN
# 19                                                     NaN
# 20                                                     NaN
# 21                                                     NaN
# 22                                                     NaN
# 23                                                     NaN
# 24                                                     NaN
# 25                                                     NaN
# 26                                                     NaN
# 27                                                     NaN
# 28                                                     NaN
# 29                                                     NaN
# ...                                                    ...
# 2373090                                                NaN
# 2373091                                                NaN
# 2373092                                                NaN
# 2373093                                                NaN
# 2373094                                                NaN
# 2373095                                                NaN
# 2373096                                                NaN
# 2373097                                                NaN
# 2373098                                                NaN
# 2373099                                                NaN
# 2373100                                                NaN
# 2373101                                                NaN
# 2373102                                                NaN
# 2373103                                                NaN
# 2373104                                                NaN
# 2373105                                                NaN
# 2373106                                                NaN
# 2373107                                                NaN
# 2373108                                                NaN
# 2373109                                                NaN
# 2373110                                                NaN
# 2373111                                                NaN
# 2373112                                                NaN
# 2373113                                                NaN
# 2373114                                                NaN
# 2373115                                                NaN
# 2373116                                                NaN
# 2373117                                                NaN
# 2373118                                                NaN
# 2373119                                                NaN
#
#          BESS-WTG01-Log-T-Raw-Rectifier2HeatSink (Average)  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
# 10                                                     NaN
# 11                                                     NaN
# 12                                                     NaN
# 13                                                     NaN
# 14                                                     NaN
# 15                                                     NaN
# 16                                                     NaN
# 17                                                     NaN
# 18                                                     NaN
# 19                                                     NaN
# 20                                                     NaN
# 21                                                     NaN
# 22                                                     NaN
# 23                                                     NaN
# 24                                                     NaN
# 25                                                     NaN
# 26                                                     NaN
# 27                                                     NaN
# 28                                                     NaN
# 29                                                     NaN
# ...                                                    ...
# 2373090                                                NaN
# 2373091                                                NaN
# 2373092                                                NaN
# 2373093                                                NaN
# 2373094                                                NaN
# 2373095                                                NaN
# 2373096                                                NaN
# 2373097                                                NaN
# 2373098                                                NaN
# 2373099                                                NaN
# 2373100                                                NaN
# 2373101                                                NaN
# 2373102                                                NaN
# 2373103                                                NaN
# 2373104                                                NaN
# 2373105                                                NaN
# 2373106                                                NaN
# 2373107                                                NaN
# 2373108                                                NaN
# 2373109                                                NaN
# 2373110                                                NaN
# 2373111                                                NaN
# 2373112                                                NaN
# 2373113                                                NaN
# 2373114                                                NaN
# 2373115                                                NaN
# 2373116                                                NaN
# 2373117                                                NaN
# 2373118                                                NaN
# 2373119                                                NaN
#
#          BESS-WTG01-Log-T-Raw-RectifierCabinetTemperature (Average)  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
# 10                                                     NaN
# 11                                                     NaN
# 12                                                     NaN
# 13                                                     NaN
# 14                                                     NaN
# 15                                                     NaN
# 16                                                     NaN
# 17                                                     NaN
# 18                                                     NaN
# 19                                                     NaN
# 20                                                     NaN
# 21                                                     NaN
# 22                                                     NaN
# 23                                                     NaN
# 24                                                     NaN
# 25                                                     NaN
# 26                                                     NaN
# 27                                                     NaN
# 28                                                     NaN
# 29                                                     NaN
# ...                                                    ...
# 2373090                                                NaN
# 2373091                                                NaN
# 2373092                                                NaN
# 2373093                                                NaN
# 2373094                                                NaN
# 2373095                                                NaN
# 2373096                                                NaN
# 2373097                                                NaN
# 2373098                                                NaN
# 2373099                                                NaN
# 2373100                                                NaN
# 2373101                                                NaN
# 2373102                                                NaN
# 2373103                                                NaN
# 2373104                                                NaN
# 2373105                                                NaN
# 2373106                                                NaN
# 2373107                                                NaN
# 2373108                                                NaN
# 2373109                                                NaN
# 2373110                                                NaN
# 2373111                                                NaN
# 2373112                                                NaN
# 2373113                                                NaN
# 2373114                                                NaN
# 2373115                                                NaN
# 2373116                                                NaN
# 2373117                                                NaN
# 2373118                                                NaN
# 2373119                                                NaN
#
#          BESS-WTG01-Log-T-Raw-ExcitationHeatSink (Average)  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
# 10                                                     NaN
# 11                                                     NaN
# 12                                                     NaN
# 13                                                     NaN
# 14                                                     NaN
# 15                                                     NaN
# 16                                                     NaN
# 17                                                     NaN
# 18                                                     NaN
# 19                                                     NaN
# 20                                                     NaN
# 21                                                     NaN
# 22                                                     NaN
# 23                                                     NaN
# 24                                                     NaN
# 25                                                     NaN
# 26                                                     NaN
# 27                                                     NaN
# 28                                                     NaN
# 29                                                     NaN
# ...                                                    ...
# 2373090                                                NaN
# 2373091                                                NaN
# 2373092                                                NaN
# 2373093                                                NaN
# 2373094                                                NaN
# 2373095                                                NaN
# 2373096                                                NaN
# 2373097                                                NaN
# 2373098                                                NaN
# 2373099                                                NaN
# 2373100                                                NaN
# 2373101                                                NaN
# 2373102                                                NaN
# 2373103                                                NaN
# 2373104                                                NaN
# 2373105                                                NaN
# 2373106                                                NaN
# 2373107                                                NaN
# 2373108                                                NaN
# 2373109                                                NaN
# 2373110                                                NaN
# 2373111                                                NaN
# 2373112                                                NaN
# 2373113                                                NaN
# 2373114                                                NaN
# 2373115                                                NaN
# 2373116                                                NaN
# 2373117                                                NaN
# 2373118                                                NaN
# 2373119                                                NaN
#
#          BESS-WTG01-Ambient-Temperature (Average)  \
# 0                                            11.0
# 1                                             NaN
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN
# 6                                             NaN
# 7                                             NaN
# 8                                             NaN
# 9                                             NaN
# 10                                            NaN
# 11                                            NaN
# 12                                            NaN
# 13                                            NaN
# 14                                            NaN
# 15                                            NaN
# 16                                            NaN
# 17                                            NaN
# 18                                            NaN
# 19                                            NaN
# 20                                           11.0
# 21                                            NaN
# 22                                            NaN
# 23                                            NaN
# 24                                            NaN
# 25                                            NaN
# 26                                            NaN
# 27                                            NaN
# 28                                            NaN
# 29                                            NaN
# ...                                           ...
# 2373090                                       NaN
# ...
# 2373110                                              NaN
# 2373111                                              NaN
# 2373112                                              NaN
# 2373113                                              NaN
# 2373114                                              NaN
# 2373115                                              NaN
# 2373116                                              NaN
# 2373117                                              NaN
# 2373118                                              NaN
# 2373119                                              NaN
#
#          BESS-WTG01-Log-T-Raw-ControlCabinetTemperature (Average)  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
# 10                                                     NaN
# 11                                                     NaN
# 12                                                     NaN
# 13                                                     NaN
# 14                                                     NaN
# 15                                                     NaN
# 16                                                     NaN
# 17                                                     NaN
# 18                                                     NaN
# 19                                                     NaN
# 20                                                     NaN
# 21                                                     NaN
# 22                                                     NaN
# 23                                                     NaN
# 24                                                     NaN
# 25                                                     NaN
# 26                                                     NaN
# 27                                                     NaN
# 28                                                     NaN
# 29                                                     NaN
# ...                                                    ...
# 2373090                                                NaN
# 2373091                                                NaN
# 2373092                                                NaN
# 2373093                                                NaN
# 2373094                                                NaN
# 2373095                                                NaN
# 2373096                                                NaN
# 2373097                                                NaN
# 2373098                                                NaN
# 2373099                                                NaN
# 2373100                                                NaN
# 2373101                                                NaN
# 2373102                                                NaN
# 2373103                                                NaN
# 2373104                                                NaN
# 2373105                                                NaN
# 2373106                                                NaN
# 2373107                                                NaN
# 2373108                                                NaN
# 2373109                                                NaN
# 2373110                                                NaN
# 2373111                                                NaN
# 2373112                                                NaN
# 2373113                                                NaN
# 2373114                                                NaN
# 2373115                                                NaN
# 2373116                                                NaN
# 2373117                                                NaN
# 2373118                                                NaN
# 2373119                                                NaN
#
#          BESS-WTG01-Log-T-Raw-TransformerTemperature (Average)  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
# 10                                                     NaN
# 11                                                     NaN
# 12                                                     NaN
# 13                                                     NaN
# 14                                                     NaN
# 15                                                     NaN
# 16                                                     NaN
# 17                                                     NaN
# 18                                                     NaN
# 19                                                     NaN
# 20                                                     NaN
# 21                                                     NaN
# 22                                                     NaN
# 23                                                     NaN
# 24                                                     NaN
# 25                                                     NaN
# 26                                                     NaN
# 27                                                     NaN
# 28                                                     NaN
# 29                                                     NaN
# ...                                                    ...
# 2373090                                                NaN
# 2373091                                                NaN
# 2373092                                                NaN
# 2373093                                                NaN
# 2373094                                                NaN
# 2373095                                                NaN
# 2373096                                                NaN
# 2373097                                                NaN
# 2373098                                                NaN
# 2373099                                                NaN
# 2373100                                                NaN
# 2373101                                                NaN
# 2373102                                                NaN
# 2373103                                                NaN
# 2373104                                                NaN
# 2373105                                                NaN
# 2373106                                                NaN
# 2373107                                                NaN
# 2373108                                                NaN
# 2373109                                                NaN
# 2373110                                                NaN
# 2373111                                                NaN
# 2373112                                                NaN
# 2373113                                                NaN
# 2373114                                                NaN
# 2373115                                                NaN
# 2373116                                                NaN
# 2373117                                                NaN
# 2373118                                                NaN
# 2373119                                                NaN
#
#          BESS-WTG01-Average blade angle across A B C (Average)  \
# 0                                                      NaN
# 1                                                      NaN
# 2                                                      NaN
# 3                                                      NaN
# 4                                                      NaN
# 5                                                      NaN
# 6                                                      NaN
# 7                                                      NaN
# 8                                                      NaN
# 9                                                      NaN
# 10                                                     NaN
# 11                                                     NaN
# 12                                                     NaN
# 13                                                     NaN
# 14                                                     NaN
# 15                                                     NaN
# 16                                                     NaN
# 17                                                     NaN
# 18                                                     NaN
# 19                                                     NaN
# 20                                                     NaN
# 21                                                     NaN
# 22                                                     NaN
# 23                                                     NaN
# 24                                                     NaN
# 25                                                     NaN
# 26                                                     NaN
# 27                                                     NaN
# 28                                                     NaN
# 29                                                     NaN
# ...                                                    ...
# 2373090                                                NaN
# 2373091                                                NaN
# 2373092                                                NaN
# 2373093                                                NaN
# 2373094                                                NaN
# 2373095                                                NaN
# 2373096                                                NaN
# 2373097                                                NaN
# 2373098                                                NaN
# 2373099                                                NaN
# 2373100                                                NaN
# 2373101                                                NaN
# 2373102                                                NaN
# 2373103                                                NaN
# 2373104                                                NaN
# 2373105                                                NaN
# 2373106                                                NaN
# 2373107                                                NaN
# 2373108                                                NaN
# 2373109                                                NaN
# 2373110                                                NaN
# 2373111                                                NaN
# 2373112                                                NaN
# 2373113                                                NaN
# 2373114                                                NaN
# 2373115                                                NaN
# 2373116                                                NaN
# 2373117                                                NaN
# 2373118                                                NaN
# 2373119                                                NaN
#
#          BESS-WTG01-WindDirection (Average)
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# 5                                       NaN
# 6                                       NaN
# 7                                       NaN
# 8                                       NaN
# 9                                       NaN
# 10                                      NaN
# 11                                      NaN
# 12                                      NaN
# 13                                      NaN
# 14                                      NaN
# 15                                      NaN
# 16                                      NaN
# 17                                      NaN
# 18                                      NaN
# 19                                      NaN
# 20                                      NaN
# 21                                      NaN
# 22                                      NaN
# 23                                      NaN
# 24                                      NaN
# 25                                      NaN
# 26                                      NaN
# 27                                      NaN
# 28                                      NaN
# 29                                      NaN
# ...                                     ...
# 2373090                                 NaN
# 2373091                                 NaN
# 2373092                                 NaN
# 2373093                                 NaN
# 2373094                                 NaN
# 2373095                                 NaN
# 2373096                                 NaN
# 2373097                                 NaN
# 2373098                                 NaN
# 2373099                                 NaN
# 2373100                                 NaN
# 2373101                                 NaN
# 2373102                                 NaN
# 2373103                                 NaN
# 2373104                                 NaN
# 2373105                                 NaN
# 2373106                                 NaN
# 2373107                                 NaN
# 2373108                                 NaN
# 2373109                                 NaN
# 2373110                                 NaN
# 2373111                                 NaN
# 2373112                                 NaN
# 2373113                                 NaN
# 2373114                                 NaN
# 2373115                                 NaN
# 2373116                                 NaN
# 2373117                                 NaN
# 2373118                                 NaN
# 2373119                                 NaN
#
# [2373120 rows x 35 columns]

# %%
list_of_wt_scada_data[0].head()
# Out:
#              TimeStamp  BESS-WTG01-WindVane (Average)  \
# 0  15-07-2017 00:00:00                            NaN
# 1  15-07-2017 00:00:30                            NaN
# 2  15-07-2017 00:01:00                            NaN
# 3  15-07-2017 00:01:30                            NaN
# 4  15-07-2017 00:02:00                            NaN
#
#    BESS-WTG01-WindSpeed (Average)  BESS-WTG01-RotorSpeed (Average)  \
# 0                             4.5                             9.75
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                              NaN
# 4                             NaN                              NaN
#
#    BESS-WTG01-NacelleDirection (Average)  BESS-WTG01-ActivePower (Average)  \
# 0                                  227.0                             109.0
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                    NaN                               NaN
# 4                                    NaN                               NaN
#
#    BESS-WTG01-Spinner-Temperature (Average)  \
# 0                                      24.0
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    BESS-WTG01-Log-T-Raw-FrontBearingTemperature (Average)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Log-T-Raw-RearBearingTemperature (Average)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Log-T-Raw-BladeAPitchHeatSink (Average)  ...  \
# 0                                                NaN   ...
# 1                                                NaN   ...
# 2                                                NaN   ...
# 3                                                NaN   ...
# 4                                                NaN   ...
#
#    BESS-WTG01-Log-T-Raw-Rectifier1HeatSink (Average)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Log-T-Raw-Rectifier2HeatSink (Average)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Log-T-Raw-RectifierCabinetTemperature (Average)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Log-T-Raw-ExcitationHeatSink (Average)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Ambient-Temperature (Average)  \
# 0                                      11.0
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    BESS-WTG01-Log-T-Raw-TowerTemperature (Average)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    BESS-WTG01-Log-T-Raw-ControlCabinetTemperature (Average)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Log-T-Raw-TransformerTemperature (Average)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Average blade angle across A B C (Average)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-WindDirection (Average)
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Slice each dataframe on the data where there is data

# %%
# This dataset is a dataset for a SINGLE wind turbine:

# Slice dataset on this row nr.: 177228 (4-09-2017 12:54:00)
#df.iloc[[177228]]

def slice_df(list_of_dataframes):
    i = 0
    for dataframe in list_of_dataframes:
        
        location = np.where(dataframe["TimeStamp"].str.contains("25-09-2017 13:20:00"))
        print(location)
        split_on_index = location[0][0]
        print(split_on_index)

        # Splitting
        df1 = dataframe.iloc[:split_on_index, :]
        df2 = dataframe.iloc[split_on_index:, :]

        # Reseting index
        df2 = df2.reset_index(drop=True)
        list_of_dataframes[i] = df2
        i+=1
        
    return list_of_dataframes

# %%
list_of_wt_scada_data = slice_df(list_of_wt_scada_data)
list_of_wt_scada_data[0].head()
# Out:
# (array([208960]),)
# 208960
#              TimeStamp  BESS-WTG01-WindVane (Average)  \
# 0  25-09-2017 13:20:00                           18.5
# 1  25-09-2017 13:20:30                            NaN
# 2  25-09-2017 13:21:00                            NaN
# 3  25-09-2017 13:21:30                           16.9
# 4  25-09-2017 13:22:00                            NaN
#
#    BESS-WTG01-WindSpeed (Average)  BESS-WTG01-RotorSpeed (Average)  \
# 0                             5.1                            13.27
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                            12.95
# 4                             NaN                              NaN
#
#    BESS-WTG01-NacelleDirection (Average)  BESS-WTG01-ActivePower (Average)  \
# 0                                  123.0                             311.0
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                  124.0                             276.0
# 4                                    NaN                               NaN
#
#    BESS-WTG01-Spinner-Temperature (Average)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    BESS-WTG01-Log-T-Raw-FrontBearingTemperature (Average)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Log-T-Raw-RearBearingTemperature (Average)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Log-T-Raw-BladeAPitchHeatSink (Average)  ...  \
# 0                                                NaN   ...
# 1                                                NaN   ...
# 2                                                NaN   ...
# 3                                                NaN   ...
# 4                                                NaN   ...
#
#    BESS-WTG01-Log-T-Raw-Rectifier1HeatSink (Average)  \
# 0                                                NaN
# 1                                                NaN
# 2                                               46.0
# 3                                                NaN
# 4                                               47.0
#
#    BESS-WTG01-Log-T-Raw-Rectifier2HeatSink (Average)  \
# 0                                                NaN
# 1                                                NaN
# 2                                               52.0
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Log-T-Raw-RectifierCabinetTemperature (Average)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Log-T-Raw-ExcitationHeatSink (Average)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Ambient-Temperature (Average)  \
# 0                                       NaN
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    BESS-WTG01-Log-T-Raw-TowerTemperature (Average)  \
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    BESS-WTG01-Log-T-Raw-ControlCabinetTemperature (Average)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Log-T-Raw-TransformerTemperature (Average)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Average blade angle across A B C (Average)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-WindDirection (Average)
# 0                          141.500000
# 1                                 NaN
# 2                                 NaN
# 3                          140.899994
# 4                                 NaN
#
# [5 rows x 35 columns]

# %% [markdown]
# ## Find index of first value in a column that is not NaN:

# %%
# Find the first non-NaN value in a column
def find_first_not_nan(df,column_name):
    ser = df[column_name].notnull()
    length = ser.shape[0]

    for i in range (length):
        if (ser[i] == True):
        return i
    return "no values in column!"

# %% [markdown]
# ## Loop through all columns in the dataset and put in the first not NaN number

# %%
# Looping all columns in dataframe
def loop_through_and_fill_first_val(data):
    for col in data.columns:
        index = find_first_not_nan(data,col)

    if (index != 0):
      # Put the value at the found index at the first index:
      data.at[0, col] = data.at[index, col]

    # Dropping columns if the first value is too far in the data set
    if (index > 200):
        data.drop([col], axis=1,inplace = True)

# %%
for dataframe in list_of_wt_scada_data:
    loop_through_and_fill_first_val(dataframe)

# %%
list_of_wt_scada_data[0].head()
# Out:
#              TimeStamp  BESS-WTG01-WindVane (Average)  \
# 0  25-09-2017 13:20:00                           18.5
# 1  25-09-2017 13:20:30                            NaN
# 2  25-09-2017 13:21:00                            NaN
# 3  25-09-2017 13:21:30                           16.9
# 4  25-09-2017 13:22:00                            NaN
#
#    BESS-WTG01-WindSpeed (Average)  BESS-WTG01-RotorSpeed (Average)  \
# 0                             5.1                            13.27
# 1                             NaN                              NaN
# 2                             NaN                              NaN
# 3                             NaN                            12.95
# 4                             NaN                              NaN
#
#    BESS-WTG01-NacelleDirection (Average)  BESS-WTG01-ActivePower (Average)  \
# 0                                  123.0                             311.0
# 1                                    NaN                               NaN
# 2                                    NaN                               NaN
# 3                                  124.0                             276.0
# 4                                    NaN                               NaN
#
#    BESS-WTG01-Spinner-Temperature (Average)  \
# 0                                      31.0
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    BESS-WTG01-Log-T-Raw-FrontBearingTemperature (Average)  \
# 0                                               41.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Log-T-Raw-RearBearingTemperature (Average)  \
# 0                                               37.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Log-T-Raw-BladeAPitchHeatSink (Average)  ...  \
# 0                                               39.0   ...
# 1                                                NaN   ...
# 2                                                NaN   ...
# 3                                                NaN   ...
# 4                                                NaN   ...
#
#    BESS-WTG01-Log-T-Raw-NacelleControlCabinetTemperature (Average)  \
# 0                                               36.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Log-T-Raw-Rectifier1HeatSink (Average)  \
# 0                                               46.0
# 1                                                NaN
# 2                                               46.0
# 3                                                NaN
# 4                                               47.0
#
#    BESS-WTG01-Log-T-Raw-Rectifier2HeatSink (Average)  \
# 0                                               52.0
# 1                                                NaN
# 2                                               52.0
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Log-T-Raw-RectifierCabinetTemperature (Average)  \
# 0                                               49.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Log-T-Raw-ExcitationHeatSink (Average)  \
# 0                                               46.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Ambient-Temperature (Average)  \
# 0                                      23.0
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
#
#    BESS-WTG01-Log-T-Raw-TowerTemperature (Average)  \
# 0                                             34.0
# 1                                              NaN
# 2                                              NaN
# 3                                              NaN
# 4                                              NaN
#
#    BESS-WTG01-Log-T-Raw-ControlCabinetTemperature (Average)  \
# 0                                               41.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-Log-T-Raw-TransformerTemperature (Average)  \
# 0                                               52.0
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    BESS-WTG01-WindDirection (Average)
# 0                          141.500000
# 1                                 NaN
# 2                                 NaN
# 3                          140.899994
# 4                                 NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Filling all missing values

# %%
def fill_missing_values(dataframe):
    # Filling in the missing values:
    dataframe.fillna(method='ffill', inplace=True)
    dataframe.head()
    return dataframe

# %%
for dataframe in list_of_wt_scada_data:
    dataframe = fill_missing_values(dataframe)
list_of_wt_scada_data[0].head()
# Out:
#              TimeStamp  BESS-WTG01-WindVane (Average)  \
# 0  25-09-2017 13:20:00                           18.5
# 1  25-09-2017 13:20:30                           18.5
# 2  25-09-2017 13:21:00                           18.5
# 3  25-09-2017 13:21:30                           16.9
# 4  25-09-2017 13:22:00                           16.9
#
#    BESS-WTG01-WindSpeed (Average)  BESS-WTG01-RotorSpeed (Average)  \
# 0                             5.1                            13.27
# 1                             5.1                            13.27
# 2                             5.1                            13.27
# 3                             5.1                            12.95
# 4                             5.1                            12.95
#
#    BESS-WTG01-NacelleDirection (Average)  BESS-WTG01-ActivePower (Average)  \
# 0                                  123.0                             311.0
# 1                                  123.0                             311.0
# 2                                  123.0                             311.0
# 3                                  124.0                             276.0
# 4                                  124.0                             276.0
#
#    BESS-WTG01-Spinner-Temperature (Average)  \
# 0                                      31.0
# 1                                      31.0
# 2                                      31.0
# 3                                      31.0
# 4                                      31.0
#
#    BESS-WTG01-Log-T-Raw-FrontBearingTemperature (Average)  \
# 0                                               41.0
# 1                                               41.0
# 2                                               41.0
# 3                                               41.0
# 4                                               41.0
#
#    BESS-WTG01-Log-T-Raw-RearBearingTemperature (Average)  \
# 0                                               37.0
# 1                                               37.0
# 2                                               37.0
# 3                                               37.0
# 4                                               37.0
#
#    BESS-WTG01-Log-T-Raw-BladeAPitchHeatSink (Average)  ...  \
# 0                                               39.0   ...
# 1                                               39.0   ...
# 2                                               39.0   ...
# 3                                               39.0   ...
# 4                                               39.0   ...
#
#    BESS-WTG01-Log-T-Raw-NacelleControlCabinetTemperature (Average)  \
# 0                                               36.0
# 1                                               36.0
# 2                                               36.0
# 3                                               36.0
# 4                                               36.0
#
#    BESS-WTG01-Log-T-Raw-Rectifier1HeatSink (Average)  \
# 0                                               46.0
# 1                                               46.0
# 2                                               46.0
# 3                                               46.0
# 4                                               47.0
#
#    BESS-WTG01-Log-T-Raw-Rectifier2HeatSink (Average)  \
# 0                                               52.0
# 1                                               52.0
# 2                                               52.0
# 3                                               52.0
# 4                                               52.0
#
#    BESS-WTG01-Log-T-Raw-RectifierCabinetTemperature (Average)  \
# 0                                               49.0
# 1                                               49.0
# 2                                               49.0
# 3                                               49.0
# 4                                               49.0
#
#    BESS-WTG01-Log-T-Raw-ExcitationHeatSink (Average)  \
# 0                                               46.0
# 1                                               46.0
# 2                                               46.0
# 3                                               46.0
# 4                                               46.0
#
#    BESS-WTG01-Ambient-Temperature (Average)  \
# 0                                      23.0
# 1                                      23.0
# 2                                      23.0
# 3                                      23.0
# 4                                      23.0
#
#    BESS-WTG01-Log-T-Raw-TowerTemperature (Average)  \
# 0                                             34.0
# 1                                             34.0
# 2                                             34.0
# 3                                             34.0
# 4                                             34.0
#
#    BESS-WTG01-Log-T-Raw-ControlCabinetTemperature (Average)  \
# 0                                               41.0
# 1                                               41.0
# 2                                               41.0
# 3                                               41.0
# 4                                               41.0
#
#    BESS-WTG01-Log-T-Raw-TransformerTemperature (Average)  \
# 0                                               52.0
# 1                                               52.0
# 2                                               52.0
# 3                                               52.0
# 4                                               52.0
#
#    BESS-WTG01-WindDirection (Average)
# 0                          141.500000
# 1                          141.500000
# 2                          141.500000
# 3                          140.899994
# 4                          140.899994
#
# [5 rows x 33 columns]

# %% [markdown]
# # The Error log

# %% [markdown]
# ### Reading the data for WT01

# %%
df_log = pd.read_excel('./DataFromBazefield/AlarmlogBessaker.xlsx')

# %% [markdown]
# #### Splitting the error log into each WT

# %%
def split_errors_on_wt(error_log):
    individual_turbine_alarm = {}
    for i in range(25):
        if(i+1 < 10):
            individual_turbine_alarm[i+1] = error_log.loc[error_log['Turbine'] == 'BESS-WTG0{0}'.format(i+1)]
        else :
            individual_turbine_alarm[i+1] = error_log.loc[error_log['Turbine'] == 'BESS-WTG{0}'.format(i+1)]

        individual_turbine_alarm[i+1] = individual_turbine_alarm[i+1].reset_index(drop=True)
    return individual_turbine_alarm

# %%
error_dict = split_errors_on_wt(df_log)

# List with 25 elements containing the dataframe of each of the 25 wind turbines at Bessaker
error_list = [*error_dict.values()]
len(error_list)
# Out:
# 25

# %% [markdown]
# ### Removing errors older than 25-09-2017

# %%
from datetime import date

for error_df in error_list:
    error_df["Start"] = pd.to_datetime(error_df['Start'])
    error_df.head()
    error_df = error_df[(error_df.Start >= date(2017, 9, 25))]

error_list[0].head()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:6: FutureWarning: Comparing Series of datetimes with 'datetime.date'.  Currently, the
# 'datetime.date' is coerced to a datetime. In the future pandas will
# not coerce, and a TypeError will be raised. To retain the current
# behavior, convert the 'datetime.date' to a datetime with
# 'pd.Timestamp'.
#        Site     Turbine                   Alarm       Code Event Type  \
# 0  Bessaker  BESS-WTG01    Status_2_Substatus_1  0.0840278          A
# 1  Bessaker  BESS-WTG01  Status_240_Substatus_0      240:0          A
# 2  Bessaker  BESS-WTG01  Status_240_Substatus_1      240:1          A
# 3  Bessaker  BESS-WTG01    Status_2_Substatus_1  0.0840278          A
# 4  Bessaker  BESS-WTG01   Status_17_Substatus_0   0.708333          A
#
#                                          Description               Start  \
# 0        N   2:1 Lack of wind - (Wind speed too low) 2019-10-06 14:56:33
# 1   R  240:0 STATUS: Remote control PC (switched on) 2019-10-02 12:26:37
# 2  R  240:1 STATUS: Remote control PC (switched off) 2019-10-02 12:24:29
# 3        N   2:1 Lack of wind - (Wind speed too low) 2019-10-02 10:01:04
# 4  N   17:0 Test safety system - (Test safety sys... 2019-10-02 10:00:04
#
#                   End  Duration   Type Unnamed: 10
# 0 2019-10-06 15:06:51  00:10:18  Alarm         NaN
# 1 2019-10-02 12:26:43  00:00:06  Alarm         NaN
# 2 2019-10-02 12:26:37  00:02:08  Alarm         NaN
# 3 2019-10-02 10:06:16  00:05:12  Alarm         NaN
# 4 2019-10-02 10:01:04  00:01:00  Alarm         NaN

# %% [markdown]
# ### Formatting the dates in the error data

# %%
# What I have: format='%Y-%m-%d %H:%M:%S').
# What I want: '%d-%m-%Y %H:%M:%S'

def format_dates(dataframe):
    dataframe['Start'] = pd.to_datetime(dataframe['Start'], format='%Y-%m-%d %H:%M:%S').dt.strftime('%d-%m-%Y %H:%M:%S')
    dataframe['End'] = pd.to_datetime(dataframe['End'], format='%Y-%m-%d %H:%M:%S').dt.strftime('%d-%m-%Y %H:%M:%S')
    return dataframe

# %%
wt = 0
for error_df in error_list:
    error_df = format_dates(error_df)
    wt += 1
error_list[3].head()
# Out:
#        Site     Turbine                   Alarm       Code Event Type  \
# 0  Bessaker  BESS-WTG04    Status_2_Substatus_1  0.0840278          A
# 1  Bessaker  BESS-WTG04    Status_2_Substatus_1  0.0840278          A
# 2  Bessaker  BESS-WTG04  Status_240_Substatus_0      240:0          A
# 3  Bessaker  BESS-WTG04  Status_240_Substatus_1      240:1          A
# 4  Bessaker  BESS-WTG04    Status_2_Substatus_1  0.0840278          A
#
#                                          Description                Start  \
# 0        N   2:1 Lack of wind - (Wind speed too low)  06-10-2019 19:08:30
# 1        N   2:1 Lack of wind - (Wind speed too low)  06-10-2019 14:54:17
# 2   R  240:0 STATUS: Remote control PC (switched on)  02-10-2019 12:26:37
# 3  R  240:1 STATUS: Remote control PC (switched off)  02-10-2019 12:24:29
# 4        N   2:1 Lack of wind - (Wind speed too low)  30-09-2019 15:06:49
#
#                    End  Duration   Type Unnamed: 10
# 0  06-10-2019 20:28:48  01:20:18  Alarm
# 1  06-10-2019 15:12:16  00:17:59  Alarm         NaN
# 2  02-10-2019 12:26:44  00:00:07  Alarm         NaN
# 3  02-10-2019 12:26:37  00:02:08  Alarm         NaN
# 4  30-09-2019 15:43:58  00:37:09  Alarm         NaN

# %% [markdown]
# ### Filtering the wanted errors

# %%
'''
Error descriptions:

    "Status_9_Substatus_8" = Generator heating - (Manual)
    "Status_62_Substatus_7" = Feeding fault - (Diff. P-set/P-actual)
    "Status_15_Substatus_1" = Turbine moist - (Turbine moist Inverter 1)
    "Status_62_Substatus_30" = Feeding fault - (Feeding safety circuit faulty)
 
    '''
selected_errors = [
    "Status_9_Substatus_8",
    "Status_62_Substatus_7",
    "Status_62_Substatus_30"
]

def remove_unnecessary_faults(dataframe):
    new_df = pd.DataFrame(columns=dataframe.columns)

    for fault in selected_errors:
        new_df = new_df.append(dataframe[ dataframe["Alarm"] == fault])
    return new_df

# %%
j = 0
for error_df in error_list:
    error_df = remove_unnecessary_faults(error_df)
    error_df.sort_values(by=['Start'], inplace = True)
    error_df.reset_index(drop=True)
    error_list[j] = error_df
    j+=1
# Out:
# ['Status_9_Substatus_8']

# %%
# The plot we are building up
import numpy as np
plot_df = pd.DataFrame(np.zeros((25, len(selected_errors))),columns = selected_errors)

# %%
import matplotlib.pyplot as plt


index = 0
for error_df in error_list:
    ser = error_df["Alarm"].value_counts()
    for i in range(len(ser.index)):
        col = ser.index[i]
        plot_df.at[index,col] = ser.values[i]
    index += 1
    
plot_df.astype(int)

# plotting 


fig, ax = plt.subplots(1, 1, figsize=(14,6))
ax.set_xlabel("Bessaker Wind Turine number",fontsize=20)
ax.set_ylabel("Frequency of faults",fontsize=20)

plt.tick_params(axis='y')
plot_df.plot.bar(ax=ax,width=0.5,stacked = True,fontsize = 11)

# %%
wt = 1
plot_df = pd.DataFrame(columns = selected_errors)
plot_df
for error_df in error_list:
    
    #print(wt)
    #wt += 1
    #print((error_df["Alarm"].value_counts()))
    # plot_balance(error_df,'Alarm',"Frequency of fault","Fault type")
    
    #df2 = pd.DataFrame(error_df["Alarm"].value_counts(), columns=selected_errors)
    #df2.plot.bar();

    
    #print ("::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::")
    # print(error_list[]].Alarm.unique())
    #error_df["Alarm"].value_counts()
# Out:
#   File "<ipython-input-511-86523ba3733b>", line 17
#     #error_df["Alarm"].value_counts()
#                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
start_time = df_log_WT01['Start'].iloc[24]
end_time = df_log_WT01['End'].iloc[24]
print(start_time)
# Out:
# 29-01-2018 09:42:34

# %%
from datetime import datetime, timedelta

def ceil_dt(dt, delta):
    return dt + (datetime.min - dt) % delta

def floor_dt(dt):
    return dt.replace(second = 0)


# For flooring starting times for an error
def floor_timestamp_start(timestamp_error_start):
    timestamp_error_start = datetime.strptime(timestamp_error_start,'%d-%m-%Y %H:%M:%S')

    # print("timestamp_error:", timestamp_error_start)
    
    timestamp_error_start = floor_dt(timestamp_error_start)
    return timestamp_error_start
    
# For ceiling ending times for an error UP
def ceil_timestamp_end(timestamp_error_end):
    timestamp_error_end = datetime.strptime(timestamp_error_end,'%d-%m-%Y %H:%M:%S')

    # print("timestamp_error:", timestamp_error_end)

    timestamp_error_end = ceil_dt(timestamp_error_end,timedelta(seconds = 30))
    return timestamp_error_end

# %%
start_time = df_log_WT01['Start'].iloc[24]
end_time = df_log_WT01['End'].iloc[24]
print(start_time)
print(end_time)
# Out:
# 29-01-2018 09:42:34
# 29-01-2018 14:38:04

# %%
floor_timestamp_start(start_time)
print(start_time)
# Out:
# 29-01-2018 09:42:34

# %%
ceil = ceil_timestamp_end(end_time)
print(ceil)
# Out:
# 2018-01-29 14:38:30

# %% [markdown]
# ### Round the errors times in df_log_WT01

# %%
df_log = df_log_WT01.copy()
df_log['Start'] = df_log['Start'].apply(lambda x:floor_timestamp_start(x))
df_log['End'] = df_log['End'].apply(lambda x: ceil_timestamp_end(x))

df_log['Start'] = pd.to_datetime(df_log['Start'], format='%d-%m-%Y %H:%M:%S').dt.strftime('%d-%m-%Y %H:%M:%S')
df_log['End'] = pd.to_datetime(df_log['End'], format='%d-%m-%Y %H:%M:%S').dt.strftime('%d-%m-%Y %H:%M:%S')
df_log.head()
# Out:
#            Site     Turbine                   Alarm      Code Event Type  \
# 161    Bessaker  BESS-WTG01    Status_9_Substatus_8  0.380556          A
# 149    Bessaker  BESS-WTG01  Status_62_Substatus_30     62:30          A
# 13116  Bessaker  BESS-WTG01  Status_62_Substatus_30     62:30          A
# 17430  Bessaker  BESS-WTG01  Status_62_Substatus_30     62:30          A
# 19068  Bessaker  BESS-WTG01    Status_9_Substatus_8  0.380556          A
#
#                                              Description                Start  \
# 161                 N   9:8 Generator heating - (Manual)  01-10-2019 09:27:00
# 149    R  62:30 Feeding fault - (Feeding safety circu...  01-10-2019 15:33:00
# 13116  R  62:30 Feeding fault - (Feeding safety circu...  02-07-2018 08:37:00
# 17430  R  62:30 Feeding fault - (Feeding safety circu...  07-01-2018 15:55:00
# 19068               N   9:8 Generator heating - (Manual)  08-11-2017 14:47:00
#
#                        End  Duration   Type Unnamed: 10
# 161    01-10-2019 15:33:30  06:05:41  Alarm         NaN
# 149    01-10-2019 15:34:00  00:00:01  Alarm         NaN
# 13116  02-07-2018 08:37:30  00:00:01  Alarm         NaN
# 17430  07-01-2018 15:55:30  00:00:01  Alarm         NaN
# 19068  08-11-2017 21:09:00  06:21:13  Alarm         NaN

# %% [markdown]
# ### Inserting new column with 0 as value in SCADA dataset

# %%
for dataframe in list_of_wt_scada_data:
    dataframe['Status'] = "Other"
list_of_wt_scada_data[0].head()
list_of_wt_scada_data[0].shape
# Out:
# (2164160, 34)

# %% [markdown]
# ### Converting to timedate (Takes a long time)

# %%
# df2['TimeStamp'] = df2['TimeStamp'].apply(lambda x: datetime.strptime(x,'%d-%m-%Y %H:%M:%S'))
# df2.head()

# df2['TimeStamp'] = df2['TimeStamp'].apply(lambda x: print(type(x))
# df2.head()

# %%
df_log["Alarm"]
# Out:
# 161        Status_9_Substatus_8
# 149      Status_62_Substatus_30
# 13116    Status_62_Substatus_30
# 17430    Status_62_Substatus_30
# 19068      Status_9_Substatus_8
# 15076      Status_9_Substatus_8
# 8706       Status_9_Substatus_8
# 8612       Status_9_Substatus_8
# 8572       Status_9_Substatus_8
# 17244    Status_62_Substatus_30
# 17242    Status_62_Substatus_30
# 5062       Status_9_Substatus_8
# 8539       Status_9_Substatus_8
# 8510       Status_9_Substatus_8
# 16391    Status_62_Substatus_30
# 8010       Status_9_Substatus_8
# 13446      Status_9_Substatus_8
# 3599       Status_9_Substatus_8
# 6932       Status_9_Substatus_8
# 9813     Status_62_Substatus_30
# 639      Status_62_Substatus_30
# 626        Status_9_Substatus_8
# 1282       Status_9_Substatus_8
# 8896       Status_9_Substatus_8
# 16998      Status_9_Substatus_8
# 16987      Status_9_Substatus_8
# Name: Alarm, dtype: object

# %%
def fill_in_labels_in_SCADA(df_scada, df_error_log):
    # Looping through the errors in the error_log
    for j in range(df_error_log.shape[0]):
        
        # The error information:
        start = df_error_log.iloc[j]["Start"]
        end = df_error_log.iloc[j]["End"]
        label = df_error_log.iloc[j]["Alarm"]
        print(label)
        
        start_index_for_error_in_SCADA = df_scada.index[df_scada['TimeStamp'] == start].tolist()[0]
        end_index_for_error_in_SCADA = df_scada.index[df_scada['TimeStamp'] == end].tolist()[0]

        count = 0
        # Filling in labels for data points in range
        for i in range(start_index_for_error_in_SCADA, end_index_for_error_in_SCADA + 1 ):
            count +=1
            df_scada.at[i,'Status'] = label
        print("Number of datapoints changed in the SCADA data: ", count)
    return df_scada

# %%
# Filling in all labels in the SCADA data:

for dataframe in list_of_wt_scada_data:
    dataframe = fill_in_labels_in_SCADA(dataframe, df_log)
# Out:
# Status_9_Substatus_8
# Number of datapoints changed in the SCADA data:  734
# Status_62_Substatus_30
# Number of datapoints changed in the SCADA data:  3
# Status_62_Substatus_30
# Number of datapoints changed in the SCADA data:  2
# Status_62_Substatus_30
# Number of datapoints changed in the SCADA data:  2
# Status_9_Substatus_8
# Number of datapoints changed in the SCADA data:  765
# Status_9_Substatus_8
# Number of datapoints changed in the SCADA data:  128
# Status_9_Substatus_8
# Number of datapoints changed in the SCADA data:  191
# Status_9_Substatus_8
# Number of datapoints changed in the SCADA data:  463
# Status_9_Substatus_8
# Number of datapoints changed in the SCADA data:  326
# Status_62_Substatus_30
# Number of datapoints changed in the SCADA data:  4
# Status_62_Substatus_30
# Number of datapoints changed in the SCADA data:  2
# Status_9_Substatus_8
# Number of datapoints changed in the SCADA data:  490
# Status_9_Substatus_8
# Number of datapoints changed in the SCADA data:  226
# Status_9_Substatus_8
# Number of datapoints changed in the SCADA data:  974
# Status_62_Substatus_30
# Number of datapoints changed in the SCADA data:  3
# Status_9_Substatus_8
# Number of datapoints changed in the SCADA data:  1084
# Status_9_Substatus_8
# Number of datapoints changed in the SCADA data:  822
# Status_9_Substatus_8
# Number of datapoints changed in the SCADA data:  367
# Status_9_Substatus_8
# Number of datapoints changed in the SCADA data:  970
# Status_62_Substatus_30
# Number of datapoints changed in the SCADA data:  3
# Status_62_Substatus_30
# Number of datapoints changed in the SCADA data:  2
# Status_9_Substatus_8
# Number of datapoints changed in the SCADA data:  491
# Status_9_Substatus_8
# Number of datapoints changed in the SCADA data:  378
# Status_9_Substatus_8
# Number of datapoints changed in the SCADA data:  966
# Status_9_Substatus_8
# Number of datapoints changed in the SCADA data:  594
# Status_9_Substatus_8
# Number of datapoints changed in the SCADA data:  311

# %%
for dataframe in list_of_wt_scada_data:
    print(dataframe.columns[1].split('-')[1],"Unique Errors : ", dataframe['Status'].unique())
    print("::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::")
# Out:
# WTG01 Unique Errors :  ['Other' 'Status_9_Substatus_8' 'Status_62_Substatus_30']
# ::::::::::::::::::::::::::::::::::::::::::::::::::::::::::::

# %% [markdown]
# ## Data balance

# %%
def plot_balance(dataframe,column,xlabel,ylabel):
    s = dataframe[column].value_counts()
    fig, ax = plt.subplots()

    # Remove the plot frame lines. They are unnecessary chartjunk.  
    ax = plt.subplot(111)  
    ax.spines["top"].set_visible(False)  
    ax.spines["right"].set_visible(False)  

    ax.get_xaxis().tick_bottom()  
    ax.get_yaxis().tick_left()  

    # Make sure your axis ticks are large enough to be easily read.  
    # You don't want your viewers squinting to read your plot.  
    plt.xticks(fontsize=14)  
    plt.yticks(fontsize=14)  

    plt.ylabel("Frequency of fault", fontsize=14)  
    plt.xlabel("Fault type", fontsize=14)  

    dataframe[column].value_counts().plot(ax=ax, kind='bar')
    plt.figure(figsize=(12, 9))

# %%
for dataframe in list_of_wt_scada_data:
    print(dataframe['Status'].value_counts())
    plot_balance(dataframe,'Status',"Frequency of fault","Fault type")
# Out:
# Other                     2153861
# Status_9_Substatus_8        10278
# Status_62_Substatus_30         21
# Name: Status, dtype: int64

# %% [markdown]
# # Building models

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix


# list_of_wt_scada_data[0].columns[1] = BESS-WTG01-WindVane (Average)
x = list_of_wt_scada_data[0].loc[:,list_of_wt_scada_data[0].columns[1]:list_of_wt_scada_data[0].columns[32]]
y = list_of_wt_scada_data[0][list_of_wt_scada_data[0].columns[33]]


X_train, X_test, y_train, y_test = train_test_split(
    x, 
    y, test_size=0.33, random_state=42,
    stratify = y
)

# %%
y_test.value_counts()
# Out:
# Other                     710774
# Status_9_Substatus_8        3392
# Status_62_Substatus_30         7
# Name: Status, dtype: int64

# %%
clf = RandomForestClassifier(n_estimators=100, max_depth=2,random_state=0,class_weight="balanced")
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight='balanced',
#                        criterion='gini', max_depth=2, max_features='auto',
#                        max_leaf_nodes=None, min_impurity_decrease=0.0,
#                        min_impurity_split=None, min_samples_leaf=1,
#                        min_samples_split=2, min_weight_fraction_leaf=0.0,
#                        n_estimators=100, n_jobs=None, oob_score=False,
#                        random_state=0, verbose=0, warm_start=False)

# %%
y_train_pred = clf.predict(X_train)
y_test_pred = clf.predict(X_test)

print(accuracy_score(y_train,y_train_pred))
print(accuracy_score(y_test,y_test_pred))
# Out:
# 0.9397470460079987
# 0.9400747437945708

# %%
labels1 = list_of_wt_scada_data[0]["Status"].unique().tolist()
labelsrev = labels.reverse()

# %%
import seaborn as sns
import matplotlib.pyplot as plt     

ax= plt.subplot()
sns.heatmap(cm, annot=True, ax = ax); #annot=True to annotate cells

# labels, title and ticks
ax.set_xlabel('Predicted labels');ax.set_ylabel('True labels'); 
ax.set_title('Confusion Matrix'); 
ax.xaxis.set_ticklabels(labelsrev); ax.yaxis.set_ticklabels(labels);

# %% [markdown]
# ### Splitting the error data on the wanted date (25-09-2017)

# %%
import seaborn as sns

fig = plt.figure(figsize = (12,6))
sns.countplot(x='TimeStamp',data = removed_columns)
plt.show()

# %%
# https://imbalanced-learn.readthedocs.io/en/stable/generated/imblearn.over_sampling.SMOTE.html

# %%
# High recall

# %%
import cmat

cm = cmat.ConfusionMatrix.create(
  # 1D arrray with ground truth labels
  y_true = y_test,
  # 2D array with predictions
  y_pred = y_test_pred,
  # (optional) List of values that might occur in y_true/y_pred
  # labels = list_of_wt_scada_data[0]["Status"].unique().tolist(),
  # (optional) List of names corresponding to labels
  #names = list_of_wt_scada_data[0]["Status"].unique().tolist()
)

# %%
cm.normalize("recall").plot()

# %%
cm.normalize("precision").plot()

# %%
cm.normalize("f1score").plot()

# %%
cm.report
# Out:
# accuracy     0.940075
# precision    0.362924
# recall       0.759713
# f1score      0.376700
# iou          0.342477
# dtype: float64

# %%
cm.class_report
# Out:
#                         precision    recall   f1score       iou  frac_support  \
# Other                    0.998832  0.940905  0.969004  0.939871      0.995241
# Status_62_Substatus_30   0.000256  0.571429  0.000512  0.000256      0.000010
# Status_9_Substatus_8     0.089683  0.766804  0.160585  0.087302      0.004750
#
#                         support
# Other                    710774
# Status_62_Substatus_30        7
# Status_9_Substatus_8       3392

# %%
# Av de vi predicted stus_62 på var 0.000256 riktig => Mange falske alarmer
# optuna
# sklearn gridsearch
