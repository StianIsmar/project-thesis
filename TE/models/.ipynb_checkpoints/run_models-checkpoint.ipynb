# %% [markdown]
# # Undersampling, SMOTE, and running models

# %% [markdown]
# ## Read Undersampled_data:

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from zipfile import ZipFile
import nbimporter

import performance_measure
import data_sampling
import split_data_set

# The three models
import decision_tree
import svm_method
import random_forest_method
# Out:
# Importing Jupyter notebook from performance_measure.ipynb
# Importing Jupyter notebook from data_sampling.ipynb
# Importing Jupyter notebook from random_forest_method.ipynb
# Importing Jupyter notebook from svm_method.ipynb
# Importing Jupyter notebook from split_data_set.ipynb
# Importing Jupyter notebook from decision_tree.ipynb

# %%
path = "../../../undersampled_data.zip"

zip_file = ZipFile(path)
undersampled_data = pd.read_csv(zip_file.open('undersampled_data.csv')) #, nrows=500000)
#data = pd.read_csv(path, compression='zip', sep=',')#, nrows=500000)

# %%
data_sampling.plot_balance(undersampled_data, 'Status')

# %%
print(undersampled_data['Status'].value_counts())
# Out:
# Other                     300000
# Status_9_Substatus_8      228668
# Status_62_Substatus_7       4098
# Status_62_Substatus_30       383
# Name: Status, dtype: int64

# %% [markdown]
# ## Do more undersampling

# %%
undersampled_data = data_sampling.undersample_dataset(undersampled_data,20000,"Other")
undersampled_data = data_sampling.undersample_dataset(undersampled_data,20000,"Status_9_Substatus_8")

# %%
data_sampling.plot_balance(undersampled_data, 'Status')

# %%
undersampled_data.head()
# Out:
#              TimeStamp   WindVane  WindSpeed  RotorSpeed  NacelleDirection  \
# 0  13-08-2019 10:56:30  -4.800000       12.0   11.929999             220.0
# 1  14-12-2018 19:19:00  70.700005        0.9    0.000000             358.0
# 2  17-07-2018 17:05:30  -7.600000        5.2   10.520000             331.0
# 3  27-06-2019 18:13:00  -1.000000        3.7    8.830000             254.0
# 4  23-05-2019 16:58:30  12.300000        1.3    0.100000             342.0
#
#    ActivePower  Spinner-Temperature  Log-T-Raw-FrontBearingTemperature  \
# 0          0.0                 24.0                               30.0
# 1          0.0                  3.0                                5.0
# 2        131.0                 34.0                               41.0
# 3         78.0                 22.0                               35.0
# 4          0.0                 23.0                               25.0
#
#    Log-T-Raw-RearBearingTemperature  Log-T-Raw-BladeAPitchHeatSink  ...  \
# 0                              31.0                           26.0  ...
# 1                               7.0                           11.0  ...
# 2                              40.0                           37.0  ...
# 3                              31.0                           22.0  ...
# 4                              26.0                           29.0  ...
#
#    Log-T-Raw-Rectifier2HeatSink  Log-T-Raw-RectifierCabinetTemperature  \
# 0                          70.0                                   37.0
# 1                           9.0                                   19.0
# 2                          55.0                                   46.0
# 3                          45.0                                   35.0
# 4                          21.0                                   31.0
#
#    Log-T-Raw-ExcitationHeatSink  Ambient-Temperature  \
# 0                          46.0                 12.0
# 1                          20.0                  1.0
# 2                          47.0                 23.0
# 3                          41.0                  8.0
# 4                          23.0                 13.0
#
#    Log-T-Raw-TowerTemperature  Log-T-Raw-ControlCabinetTemperature  \
# 0                        19.0                                 22.0
# 1                         4.0                                 16.0
# 2                        -2.0                                 41.0
# 3                       -20.0                                 21.0
# 4                        16.0                                 23.0
#
#    Log-T-Raw-TransformerTemperature  Average blade angle across A B C  \
# 0                              38.0                         21.090000
# 1                              22.0                         60.049999
# 2                              57.0                          1.000000
# 3                              37.0                          1.000000
# 4                              38.0                         60.049999
#
#    WindDirection                Status
# 0     215.199997  Status_9_Substatus_8
# 1     -68.700005  Status_9_Substatus_8
# 2     323.399994                 Other
# 3     253.000000  Status_9_Substatus_8
# 4     354.299988  Status_9_Substatus_8
#
# [5 rows x 36 columns]

# %%
X = undersampled_data.drop(columns = ['Status', 'TimeStamp'])
y = undersampled_data.Status
y.shape
# Out:
# (44481,)

# %%
y.value_counts()
# Out:
# Status_9_Substatus_8      20000
# Other                     20000
# Status_62_Substatus_7      4098
# Status_62_Substatus_30      383
# Name: Status, dtype: int64

# %% [markdown]
# ## Split into training and test

# %%
X_train, X_test, y_train, y_test = split_data_set.split_data(X,y)

# %%
columns_for_data = X_train.columns

# %%
y_train.value_counts()
# Out:
# Status_9_Substatus_8      13400
# Other                     13400
# Status_62_Substatus_7      2746
# Status_62_Substatus_30      256
# Name: Status, dtype: int64

# %%
y_test.value_counts()
# Out:
# Status_9_Substatus_8      6600
# Other                     6600
# Status_62_Substatus_7     1352
# Status_62_Substatus_30     127
# Name: Status, dtype: int64

# %% [markdown]
# ## Random forest and feature importance

# %%
rf = random_forest_method.get_rf_model(X_train, X_test, y_train, y_test)
# Out:
# Normalized confusion matrix
# [[9.87575758e-01 3.03030303e-04 3.03030303e-03 9.09090909e-03]
#  [1.57480315e-01 8.42519685e-01 0.00000000e+00 0.00000000e+00]
#  [2.21893491e-03 0.00000000e+00 9.97781065e-01 0.00000000e+00]
#  [1.72727273e-02 0.00000000e+00 1.51515152e-04 9.82575758e-01]]
# Total Accuracy 		0.985
#
# Status 				 Precision 	 Recall 	 F1
# ----------------------------------------------------------------------
# Other                     	 0.979 		 0.988 		 0.983
# Status_62_Substatus_30    	 0.982 		 0.843 		 0.907
# Status_62_Substatus_7     	 0.985 		 0.998 		 0.991
# Status_9_Substatus_8      	 0.991 		 0.983 		 0.987

# %%
rf
# Out:
#                                             importance
# ActivePower                                   0.162597
# Log-T-Raw-Rectifier1HeatSink                  0.083453
# Log-T-Raw-TransformerTemperature              0.069904
# Log-T-Raw-Rotor2Temperature                   0.063931
# Log-T-Raw-Rotor1Temperature                   0.044546
# Log-T-Raw-Stator2Temperature                  0.041546
# Log-T-Raw-Rectifier2HeatSink                  0.037996
# Log-T-Raw-Stator1Temperature                  0.037608
# Log-T-Raw-NacelleAmbientTemperature           0.032311
# Log-T-Raw-RearBearingTemperature              0.030254
# Average blade angle across A B C              0.029369
# RotorSpeed                                    0.029360
# Spinner-Temperature                           0.027976
# Log-T-Raw-ControlCabinetTemperature           0.027432
# Log-T-Raw-TowerTemperature                    0.024807
# Log-T-Raw-ExcitationHeatSink                  0.024134
# Ambient-Temperature                           0.023403
# Log-T-Raw-FrontBearingTemperature             0.023369
# NacelleDirection                              0.023335
# Nacelle-Temperature                           0.020504
# Log-T-Raw-RectifierCabinetTemperature         0.017845
# Log-T-Raw-NacelleControlCabinetTemperature    0.016273
# Log-T-Raw-BladeAPitchControlBox               0.015610
# WindDirection                                 0.012761
# WindSpeed                                     0.012745
# Log-T-Raw-BladeAPitchHeatSink                 0.012226
# Log-T-Raw-BladeCPitchControlBox               0.011958
# Log-T-Raw-BladeCPitchHeatSink                 0.010597
# Log-T-Raw-BladeBPitchControlBox               0.010354
# Log-T-Raw-BladeBPitchHeatSink                 0.007914
# WindVane                                      0.005936
# Log-T-Raw-BladeATemperature                   0.002785
# Log-T-Raw-BladeBTemperature                   0.002712
# Log-T-Raw-BladeCTemperature                   0.002452

# %% [markdown]
# ## Scale dataset for SVM

# %%
from sklearn.preprocessing import MinMaxScaler

from sklearn import preprocessing

scaler  = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
print(X_train_scaled.shape)
print(X_test_scaled.shape)

X_train_scaled_df = pd.DataFrame(X_train_scaled)
X_train_scaled_df.columns = columns_for_data
X_train_scaled_df.head()
# Out:
# (29802, 34)
# (14679, 34)
#    WindVane  WindSpeed  RotorSpeed  NacelleDirection  ActivePower  \
# 0  0.459054   0.057377    0.226707          0.231198     0.000000
# 1  0.985548   0.019126    0.000000          0.364903     0.000000
# 2  0.481723   0.062842    0.264062          0.133705     0.000416
# 3  0.486540   0.226776    0.089309          0.969359     0.000000
# 4  0.494758   0.344262    0.705453          0.345404     0.208663
#
#    Spinner-Temperature  Log-T-Raw-FrontBearingTemperature  \
# 0             0.618421                           0.616279
# 1             0.421053                           0.476744
# 2             0.434211                           0.465116
# 3             0.552632                           0.534884
# 4             0.657895                           0.767442
#
#    Log-T-Raw-RearBearingTemperature  Log-T-Raw-BladeAPitchHeatSink  \
# 0                          0.324675                       0.746667
# 1                          0.246753                       0.546667
# 2                          0.253247                       0.520000
# 3                          0.311688                       0.613333
# 4                          0.376623                       0.760000
#
#    Log-T-Raw-BladeBPitchHeatSink  ...  Log-T-Raw-Rectifier1HeatSink  \
# 0                       0.767123  ...                      0.354839
# 1                       0.575342  ...                      0.150538
# 2                       0.547945  ...                      0.193548
# 3                       0.630137  ...                      0.139785
# 4                       0.780822  ...                      0.666667
#
#    Log-T-Raw-Rectifier2HeatSink  Log-T-Raw-RectifierCabinetTemperature  \
# 0                      0.395349                               0.740741
# 1                      0.174419                               0.407407
# 2                      0.220930                               0.481481
# 3                      0.162791                               0.444444
# 4                      0.720930                               0.703704
#
#    Log-T-Raw-ExcitationHeatSink  Ambient-Temperature  \
# 0                      0.404255             0.541667
# 1                      0.095745             0.270833
# 2                      0.329787             0.291667
# 3                      0.053191             0.291667
# 4                      0.489362             0.645833
#
#    Log-T-Raw-TowerTemperature  Log-T-Raw-ControlCabinetTemperature  \
# 0                    0.542169                                 0.42
# 1                    0.373494                                 0.32
# 2                    0.361446                                 0.48
# 3                    0.421687                                 0.20
# 4                    0.650602                                 0.56
#
#    Log-T-Raw-TransformerTemperature  Average blade angle across A B C  \
# 0                          0.330097                          0.000000
# 1                          0.233010                          0.636197
# 2                          0.203883                          0.000000
# 3                          0.407767                          0.636520
# 4                          0.398058                          0.213970
#
#    WindDirection
# 0       0.407354
# 1       0.884985
# 2       0.352196
# 3       0.968539
# 4       0.516854
#
# [5 rows x 34 columns]

# %% [markdown]
# ## SVM method

# %% [markdown]
# ### BALANCED SVM

# %%
# Balanced
svm1 = svm_method.get_svm_model_balanced(X_train_scaled, X_test_scaled, y_train, y_test)
# Out:
# Loading...
# Training...
# Training Complete
# Plotting Confusion Matrix...
# Normalized confusion matrix
# [[0.41121212 0.32484848 0.12954545 0.13439394]
#  [0.18110236 0.66929134 0.09448819 0.05511811]
#  [0.02440828 0.01183432 0.90976331 0.05399408]
#  [0.1069697  0.25257576 0.01469697 0.62575758]]
# Plotting Performance Measure...
# Total Accuracy 		0.556
#
# Status 				 Precision 	 Recall 	 F1
# ----------------------------------------------------------------------
# Other                     	 0.781 		 0.411 		 0.539
# Status_62_Substatus_30    	 0.022 		 0.669 		 0.042
# Status_62_Substatus_7     	 0.561 		 0.910 		 0.694
# Status_9_Substatus_8      	 0.810 		 0.626 		 0.706

# %% [markdown]
# ### UNBALANCED SVM

# %%
# Unbalanced
svm2 = svm_method.get_svm_model(X_train_scaled, X_test_scaled, y_train, y_test)
# Out:
# Loading...
# Training...
# Training Complete
# Plotting Confusion Matrix...
# Normalized confusion matrix
# [[8.63636364e-01 0.00000000e+00 1.15151515e-02 1.24848485e-01]
#  [8.97637795e-01 0.00000000e+00 0.00000000e+00 1.02362205e-01]
#  [4.57100592e-01 0.00000000e+00 4.88165680e-01 5.47337278e-02]
#  [3.50303030e-01 0.00000000e+00 7.57575758e-04 6.48939394e-01]]
# Plotting Performance Measure...
# Total Accuracy 		0.725
#
# Status 				 Precision 	 Recall 	 F1
# ----------------------------------------------------------------------
# Other                     	 0.652 		 0.864 		 0.743
# Status_62_Substatus_7     	 0.891 		 0.488 		 0.631
# Status_9_Substatus_8      	 0.825 		 0.649 		 0.726

# %% [markdown]
# ### SMOTE (Synthetic Minority Oversampling Technique)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=12)
X_train_scaled_smote ,y_train_smote = sm.fit_resample(X_train_scaled, y_train)


X_test_scaled_smote ,y_test_smote = sm.fit_resample(X_test_scaled, y_test)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
y1 = pd.DataFrame(X_train_scaled_smote)
y1[0].value_counts()
# Out:
# 0.470388    300
# 0.491357    288
# 0.484557    286
# 0.503825    276
# 0.496741    259
#            ...
# 0.510231      1
# 0.479136      1
# 0.476516      1
# 0.474220      1
# 1.000000      1
# Name: 0, Length: 20140, dtype: int64

# %% [markdown]
# ### SMOTE and unbalanced weights (USE THIS RESULT Best results for 62_30)!

# %%
svm3 = svm_method.get_svm_model(X_train_scaled_smote, X_test_scaled_smote, y_train_smote, y_test_smote)
# Out:
# Loading...
# Training...
# Training Complete
# Plotting Confusion Matrix...
# Normalized confusion matrix
# [[0.46863636 0.32166667 0.11424242 0.09545455]
#  [0.18075758 0.70409091 0.08651515 0.02863636]
#  [0.02045455 0.005      0.92181818 0.05272727]
#  [0.1169697  0.26075758 0.0130303  0.60924242]]
# Plotting Performance Measure...
# Total Accuracy 		0.676
#
# Status 				 Precision 	 Recall 	 F1
# ----------------------------------------------------------------------
# Other                     	 0.596 		 0.469 		 0.525
# Status_62_Substatus_30    	 0.545 		 0.704 		 0.615
# Status_62_Substatus_7     	 0.812 		 0.922 		 0.863
# Status_9_Substatus_8      	 0.775 		 0.609 		 0.682

# %% [markdown]
# ### SMOTE and class_weight balanced

# %%
print(X_train_scaled_smote.shape)
print(y_train.shape)
print(X_test_scaled_smote.shape)
print(y_test.shape)
# Out:
# (53600, 34)
# (29802,)
# (26400, 34)
# (14679,)

# %%
# balanced with smote and undersampling
svm4 = svm_method.get_svm_model_balanced(X_train_scaled_smote, X_test_scaled_smote, y_train_smote, y_test_smote)
# Out:
# Loading...
# Training...

# %% [markdown]
# ## Decision tree model

# %%
# Remove the features from the random forest model called rf
rf_df = pd.DataFrame(rf)
rf_df_extracted = rf_df.head(6)
rf_df_extracted.reset_index()
include_features = rf_df_extracted.index
list_of_features = include_features.tolist()

# The selected features in a list
df_selected_features = pd.DataFrame(list_of_features)
df_selected_features.columns = ['Selected features for decision tree']
df_selected_features

# %%
import numpy as np

X_train_scaled_with_names = (pd.DataFrame(X_train_scaled))
X_train_scaled_with_names.columns = columns_for_data

X_test_scaled_with_names = (pd.DataFrame(X_test_scaled))
X_test_scaled_with_names.columns = columns_for_data

# data = X_train_scaled_with_names[np.intersect1d(X_train_scaled_with_names, list_of_features)]


X_train_scaled_removed = X_train_scaled_with_names[include_features.tolist()]
X_test_scaled_removed = X_test_scaled_with_names[include_features.tolist()]

# Printing df
X_test_scaled_removed.head()

# %%
# Train DT on these features and print it out:
dt = decision_tree.get_decision_tree_model(X_train_scaled_removed, X_test_scaled_removed, y_train, y_test)
print("depth",dt.get_depth())

# %%
# Print the tree
import pydotplus
from sklearn.datasets import load_iris
from sklearn import tree
import collections


dot_data = tree.export_graphviz(dt,
                                feature_names=X_test_scaled_removed.columns,
                                out_file=None,
                                filled=True,
                                rounded=True)
graph = pydotplus.graph_from_dot_data(dot_data)

colors = ('brown', 'forestgreen')
edges = collections.defaultdict(list)

for edge in graph.get_edge_list():
    edges[edge.get_source()].append(int(edge.get_destination()))

for edge in edges:
    edges[edge].sort()    
    for i in range(2):
        dest = graph.get_node(str(edges[edge][i]))[0]
        dest.set_fillcolor(colors[i])

# Exporting image to current directory
graph.write_png('tree2.png')
