# %% [markdown]
# ## Read Undersampled_data:

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from zipfile import ZipFile
import nbimporter
import random_forest_method
import performance_measure
from sklearn.preprocessing import MinMaxScaler
import svm_method
import data_sampling
import split_data_set

# %%
path = "../../../undersampled_data.zip"

zip_file = ZipFile(path)
undersampled_data = pd.read_csv(zip_file.open('undersampled_data.csv')) #, nrows=500000)
#data = pd.read_csv(path, compression='zip', sep=',')#, nrows=500000)

# %%
data_sampling.plot_balance(undersampled_data, 'Status')

# %%
print(undersampled_data['Status'].value_counts())
# Out:
# Other                     300000
# Status_9_Substatus_8      228668
# Status_62_Substatus_7       4098
# Status_62_Substatus_30       383
# Name: Status, dtype: int64

# %% [markdown]
# ## Do more undersampling

# %%
undersampled_data = data_sampling.undersample_dataset(undersampled_data,50000,"Other")
undersampled_data = data_sampling.undersample_dataset(undersampled_data,50000,"Status_9_Substatus_8")

# %%
data_sampling.plot_balance(undersampled_data, 'Status')

# %%
X = undersampled_data.drop(columns = ['Status', 'TimeStamp'])
y = undersampled_data.Status
X.shape
# Out:
# (104481, 34)

# %%
y.value_counts()
# Out:
# Status_9_Substatus_8      50000
# Other                     50000
# Status_62_Substatus_7      4098
# Status_62_Substatus_30      383
# Name: Status, dtype: int64

# %% [markdown]
# ### Split into training and test

# %%
X_train, X_test, y_train, y_test = split_data_set.split_data(X,y)

# %%
y_train.value_counts()
# Out:
# Status_9_Substatus_8      33500
# Other                     33500
# Status_62_Substatus_7      2746
# Status_62_Substatus_30      256
# Name: Status, dtype: int64

# %%
y_test.value_counts()
# Out:
# Status_9_Substatus_8      16500
# Other                     16500
# Status_62_Substatus_7      1352
# Status_62_Substatus_30      127
# Name: Status, dtype: int64

# %% [markdown]
# ## Random forest and feature importance

# %%
rf = random_forest_method.get_rf_model(X_train, X_test, y_train, y_test)
# Out:
# Normalized confusion matrix
# [[9.90363636e-01 0.00000000e+00 2.96969697e-03 6.66666667e-03]
#  [2.44094488e-01 7.40157480e-01 0.00000000e+00 1.57480315e-02]
#  [3.69822485e-03 0.00000000e+00 9.96301775e-01 0.00000000e+00]
#  [4.36363636e-03 6.06060606e-05 0.00000000e+00 9.95575758e-01]]
# Total Accuracy 		0.992
#
# Status 				 Precision 	 Recall 	 F1
# ----------------------------------------------------------------------
# Other                     	 0.993 		 0.990 		 0.992
# Status_62_Substatus_30    	 0.989 		 0.740 		 0.847
# Status_62_Substatus_7     	 0.965 		 0.996 		 0.980
# Status_9_Substatus_8      	 0.993 		 0.996 		 0.994

# %%
rf
# Out:
#                                             importance
# ActivePower                                   0.180287
# Log-T-Raw-Rectifier1HeatSink                  0.088717
# Log-T-Raw-TransformerTemperature              0.078690
# Log-T-Raw-Stator2Temperature                  0.044111
# Log-T-Raw-Rotor2Temperature                   0.037998
# RotorSpeed                                    0.035518
# Log-T-Raw-Rotor1Temperature                   0.035215
# Log-T-Raw-NacelleAmbientTemperature           0.034057
# Log-T-Raw-Rectifier2HeatSink                  0.033440
# Average blade angle across A B C              0.033212
# Log-T-Raw-Stator1Temperature                  0.032523
# Log-T-Raw-FrontBearingTemperature             0.029948
# Log-T-Raw-RearBearingTemperature              0.027576
# Ambient-Temperature                           0.027546
# Log-T-Raw-TowerTemperature                    0.025859
# Spinner-Temperature                           0.024945
# Log-T-Raw-ControlCabinetTemperature           0.022874
# Log-T-Raw-ExcitationHeatSink                  0.022284
# NacelleDirection                              0.018716
# Nacelle-Temperature                           0.017927
# Log-T-Raw-BladeAPitchHeatSink                 0.017168
# WindDirection                                 0.016251
# WindSpeed                                     0.014875
# Log-T-Raw-RectifierCabinetTemperature         0.014773
# Log-T-Raw-NacelleControlCabinetTemperature    0.014568
# Log-T-Raw-BladeAPitchControlBox               0.013209
# Log-T-Raw-BladeBPitchHeatSink                 0.012722
# Log-T-Raw-BladeCPitchHeatSink                 0.011286
# Log-T-Raw-BladeCPitchControlBox               0.010172
# Log-T-Raw-BladeBPitchControlBox               0.010066
# WindVane                                      0.004480
# Log-T-Raw-BladeCTemperature                   0.003807
# Log-T-Raw-BladeBTemperature                   0.002859
# Log-T-Raw-BladeATemperature                   0.002321

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### Scale dataset

# %%
print(X_train.shape)

scaler  = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
print(X_train_scaled.shape)
# Out:
# (70002, 34)
# (70002, 34)

# %%
scaler = MinMaxScaler(copy=False)
X_train_scaled = scaler.fit(X_train)
X_train_scaled = X_train_scaled.transform(X_train)
X_train = pd.DataFrame(X_train_scaled, columns=list(X))
X_train.head(10)

X_test_scaled = scaler.fit(X_test)
X_test_scaled = X_test_scaled.transform(X_test)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=list(X))
X_test_scaled.head(10)
# Out:
#    WindVane  WindSpeed  RotorSpeed  NacelleDirection  ActivePower  \
# 0  0.508023   0.125641    0.512237          0.727019     0.000000
# 1  0.515473   0.164103    0.510949          0.320334     0.000000
# 2  0.483381   0.182051    0.507085          0.676880     0.000000
# 3  0.453868   0.284615    0.822241          0.398329     0.379109
# 4  0.500000   0.556410    0.892658          0.590529     0.978777
# 5  0.673066   0.164103    0.000000          0.467967     0.000000
# 6  0.482521   0.215385    0.714040          0.662953     0.257595
# 7  0.479370   0.205128    0.652641          0.685237     0.208073
# 8  0.463610   0.248718    0.498497          0.752089     0.000000
# 9  0.511748   0.366667    0.932589          0.754875     0.981273
#
#    Spinner-Temperature  Log-T-Raw-FrontBearingTemperature  \
# 0             0.526316                           0.322581
# 1             0.539474                           0.283871
# 2             0.592105                           0.367742
# 3             0.605263                           0.393548
# 4             0.789474                           0.470968
# 5             0.500000                           0.238710
# 6             0.513158                           0.335484
# 7             0.710526                           0.425806
# 8             0.421053                           0.303226
# 9             0.592105                           0.451613
#
#    Log-T-Raw-RearBearingTemperature  Log-T-Raw-BladeAPitchHeatSink  \
# 0                          0.620253                       0.545455
# 1                          0.607595                       0.454545
# 2                          0.658228                       0.625000
# 3                          0.569620                       0.454545
# 4                          0.544304                       0.556818
# 5                          0.493671                       0.556818
# 6                          0.607595                       0.522727
# 7                          0.772152                       0.636364
# 8                          0.544304                       0.443182
# 9                          0.670886                       0.454545
#
#    Log-T-Raw-BladeBPitchHeatSink  ...  Log-T-Raw-Rectifier1HeatSink  \
# 0                       0.558140  ...                      0.860465
# 1                       0.465116  ...                      0.860465
# 2                       0.616279  ...                      0.848837
# 3                       0.488372  ...                      0.581395
# 4                       0.581395  ...                      0.720930
# 5                       0.558140  ...                      0.197674
# 6                       0.534884  ...                      0.755814
# 7                       0.651163  ...                      0.732558
# 8                       0.465116  ...                      0.837209
# 9                       0.476744  ...                      0.651163
#
#    Log-T-Raw-Rectifier2HeatSink  Log-T-Raw-RectifierCabinetTemperature  \
# 0                      0.882353                               0.590164
# 1                      0.835294                               0.393443
# 2                      0.788235                               0.639344
# 3                      0.658824                               0.426230
# 4                      0.788235                               0.344262
# 5                      0.211765                               0.360656
# 6                      0.670588                               0.508197
# 7                      0.729412                               0.639344
# 8                      0.858824                               0.442623
# 9                      0.741176                               0.262295
#
#    Log-T-Raw-ExcitationHeatSink  Ambient-Temperature  \
# 0                      0.531915             0.384615
# 1                      0.457447             0.192308
# 2                      0.521277             0.519231
# 3                      0.510638             0.403846
# 4                      0.382979             0.442308
# 5                      0.159574             0.519231
# 6                      0.478723             0.480769
# 7                      0.478723             0.519231
# 8                      0.457447             0.288462
# 9                      0.319149             0.326923
#
#    Log-T-Raw-TowerTemperature  Log-T-Raw-ControlCabinetTemperature  \
# 0                    0.458824                             0.293103
# 1                    0.364706                             0.431034
# 2                    0.517647                             0.396552
# 3                    0.564706                             0.482759
# 4                    0.741176                             0.637931
# 5                    0.529412                             0.603448
# 6                    0.564706                             0.448276
# 7                    0.564706                             0.500000
# 8                    0.376471                             0.224138
# 9                    0.588235                             0.482759
#
#    Log-T-Raw-TransformerTemperature  Average blade angle across A B C  \
# 0                          0.323232                          0.036434
# 1                          0.222222                          0.153713
# 2                          0.373737                          0.106069
# 3                          0.636364                          0.000000
# 4                          0.868687                          0.201789
# 5                          0.363636                          0.980813
# 6                          0.323232                          0.000000
# 7                          0.454545                          0.000000
# 8                          0.232323                          0.184542
# 9                          0.626263                          0.046351
#
#    WindDirection
# 0       0.793229
# 1       0.485965
# 2       0.736233
# 3       0.499893
# 4       0.682237
# 5       0.717377
# 6       0.724877
# 7       0.739661
# 8       0.779301
# 9       0.817442
#
# [10 rows x 34 columns]

# %% [markdown]
# ### SVM method

# %%
svm_method.get_svm_model(X_train_scaled, X_test_scaled, y_train, y_test)
# Out:
# Loading...
# Training...
# Training Complete
# Plotting Confusion Matrix...
# Normalized confusion matrix
# [[0.90909091 0.         0.         0.09090909]
#  [0.8976378  0.         0.         0.1023622 ]
#  [0.94822485 0.         0.         0.05177515]
#  [0.34581818 0.         0.         0.65418182]]
# Plotting Performance Measure...
# Total Accuracy 		0.748
#
# Status 				 Precision 	 Recall 	 F1
# ----------------------------------------------------------------------
# Other                     	 0.679 		 0.909 		 0.777
# Status_9_Substatus_8      	 0.872 		 0.654 		 0.748
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='auto', kernel='poly',
#     max_iter=-1, probability=False, random_state=12, shrinking=True, tol=0.001,
#     verbose=False)

# %% [markdown]
# ### SMOTE (Synthetic Minority Oversampling Technique):

# %%
sm = SMOTE(random_state=12)
X_
