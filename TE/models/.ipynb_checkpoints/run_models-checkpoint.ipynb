# %% [markdown]
# ## Read Undersampled_data:

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from zipfile import ZipFile
from sklearn.preprocessing import MinMaxScaler

import nbimporter
import random_forest_method
import performance_measure
import svm_method
import data_sampling
import split_data_set
import target_parser
# Out:
# Importing Jupyter notebook from random_forest_method.ipynb
# Importing Jupyter notebook from performance_measure.ipynb
# Importing Jupyter notebook from svm_method.ipynb
# Importing Jupyter notebook from data_sampling.ipynb
# Importing Jupyter notebook from split_data_set.ipynb
# Importing Jupyter notebook from target_parser.ipynb
# Traceback (most recent call last):
#
#   File "/Users/mortenolsenosvik/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 3267, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-1-6fd22862acd4>", line 13, in <module>
#     import target_parser
#
#   File "<frozen importlib._bootstrap>", line 983, in _find_and_load
#
#   File "<frozen importlib._bootstrap>", line 967, in _find_and_load_unlocked
#
#   File "<frozen importlib._bootstrap>", line 668, in _load_unlocked
#
#   File "<frozen importlib._bootstrap>", line 638, in _load_backward_compatible
#
#   File "/Users/mortenolsenosvik/anaconda3/lib/python3.7/site-packages/nbimporter.py", line 102, in load_module
#     code = self.shell.input_transformer_manager.transform_cell(cell.source)
#
#   File "/Users/mortenolsenosvik/anaconda3/lib/python3.7/site-packages/IPython/core/inputtransformer2.py", line 576, in transform_cell
#     lines = self.do_token_transforms(lines)
#
#   File "/Users/mortenolsenosvik/anaconda3/lib/python3.7/site-packages/IPython/core/inputtransformer2.py", line 561, in do_token_transforms
#     changed, lines = self.do_one_token_transform(lines)
#
#   File "/Users/mortenolsenosvik/anaconda3/lib/python3.7/site-packages/IPython/core/inputtransformer2.py", line 541, in do_one_token_transform
#     tokens_by_line = make_tokens_by_line(lines)
#
#   File "/Users/mortenolsenosvik/anaconda3/lib/python3.7/site-packages/IPython/core/inputtransformer2.py", line 471, in make_tokens_by_line
#     for token in tokenize.generate_tokens(iter(lines).__next__):
#
#   File "/Users/mortenolsenosvik/anaconda3/lib/python3.7/tokenize.py", line 572, in _tokenize
#     ("<tokenize>", lnum, pos, line))
#
#   File "<tokenize>", line 53
#     y['Status'] = y['Status'].map(statusToNumb)
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
path = "../../../undersampled_data.zip"

zip_file = ZipFile(path)
undersampled_data = pd.read_csv(zip_file.open('undersampled_data.csv')) #, nrows=500000)
#data = pd.read_csv(path, compression='zip', sep=',')#, nrows=500000)

# %%
data_sampling.get_statues_percentage(undersampled_data, 'Undersampled dataset to max size 300 000:\n')
data_sampling.plot_balance(undersampled_data, 'Status')

# %% [markdown]
# ## Do more undersampling

# %%
undersampled_data = data_sampling.undersample_dataset(undersampled_data,50000,"Other")
undersampled_data = data_sampling.undersample_dataset(undersampled_data,50000,"Status_9_Substatus_8")

# %%
data_sampling.get_statues_percentage(undersampled_data, 'Undersampled dataset to max size 50 000:\n')
data_sampling.plot_balance(undersampled_data, 'Status')

# %%
X = undersampled_data.drop(columns = ['Status', 'TimeStamp'])
y = undersampled_data[['Status']]
X.shape

# %%
y

# %% [markdown]
# ### Translate status codes to int for easier comparison

# %%
target_parser.status_to_code(y)
y

# %%
y.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-3d1fed58b86b> in <module>
# ----> 1 y.value_counts()
#
# NameError: name 'y' is not defined

# %% [markdown]
# ### Split into training and test

# %%
X_train, X_test, y_train, y_test = split_data_set.split_data(X,y)

# %%
y_train.value_counts()
# Out:
# Status_9_Substatus_8      33500
# Other                     33500
# Status_62_Substatus_7      2746
# Status_62_Substatus_30      256
# Name: Status, dtype: int64

# %% [markdown]
# ## Random forest and feature importance

# %%
rf = random_forest_method.get_rf_model(X_train, X_test, y_train, y_test)
# Out:
# Normalized confusion matrix
# [[9.91818182e-01 1.21212121e-04 2.60606061e-03 5.45454545e-03]
#  [1.96850394e-01 8.03149606e-01 0.00000000e+00 0.00000000e+00]
#  [2.95857988e-03 0.00000000e+00 9.97041420e-01 0.00000000e+00]
#  [3.63636364e-03 1.81818182e-04 0.00000000e+00 9.96181818e-01]]
# Total Accuracy 		0.993
#
# Status 				 Precision 	 Recall 	 F1
# ----------------------------------------------------------------------
# Other                     	 0.995 		 0.992 		 0.993
# Status_62_Substatus_30    	 0.953 		 0.803 		 0.872
# Status_62_Substatus_7     	 0.969 		 0.997 		 0.983
# Status_9_Substatus_8      	 0.995 		 0.996 		 0.995

# %%
rf
# Out:
#                                             importance
# ActivePower                                   0.165590
# Log-T-Raw-TransformerTemperature              0.088249
# Log-T-Raw-Rectifier1HeatSink                  0.087737
# Log-T-Raw-Stator2Temperature                  0.048115
# Average blade angle across A B C              0.045301
# Log-T-Raw-Rectifier2HeatSink                  0.043441
# Log-T-Raw-Rotor1Temperature                   0.039046
# Log-T-Raw-Rotor2Temperature                   0.037355
# Log-T-Raw-Stator1Temperature                  0.035769
# Log-T-Raw-NacelleAmbientTemperature           0.033071
# Log-T-Raw-RearBearingTemperature              0.027719
# Log-T-Raw-FrontBearingTemperature             0.027589
# Ambient-Temperature                           0.027545
# Log-T-Raw-ControlCabinetTemperature           0.026708
# Log-T-Raw-TowerTemperature                    0.023424
# RotorSpeed                                    0.022962
# Spinner-Temperature                           0.022637
# NacelleDirection                              0.020878
# Log-T-Raw-NacelleControlCabinetTemperature    0.018886
# Log-T-Raw-ExcitationHeatSink                  0.017810
# Nacelle-Temperature                           0.016094
# WindSpeed                                     0.014252
# WindDirection                                 0.014103
# Log-T-Raw-BladeAPitchHeatSink                 0.012844
# Log-T-Raw-BladeAPitchControlBox               0.012766
# Log-T-Raw-RectifierCabinetTemperature         0.012456
# Log-T-Raw-BladeBPitchHeatSink                 0.012327
# Log-T-Raw-BladeCPitchHeatSink                 0.010795
# Log-T-Raw-BladeBPitchControlBox               0.010295
# Log-T-Raw-BladeCPitchControlBox               0.009440
# WindVane                                      0.005277
# Log-T-Raw-BladeBTemperature                   0.003915
# Log-T-Raw-BladeATemperature                   0.003265
# Log-T-Raw-BladeCTemperature                   0.002338

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### Scale dataset

# %%
print(X_train.shape)

scaler  = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
print(X_train_scaled.shape)
# Out:
# (70002, 34)
# (70002, 34)

# %%
scaler = MinMaxScaler(copy=False)
X_train_scaled = scaler.fit(X_train)
X_train_scaled = X_train_scaled.transform(X_train)
X_train = pd.DataFrame(X_train_scaled, columns=list(X))
X_train.head(10)

X_test_scaled = scaler.fit(X_test)
X_test_scaled = X_test_scaled.transform(X_test)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=list(X))
X_test_scaled.head(10)
# Out:
#    WindVane  WindSpeed  RotorSpeed  NacelleDirection  ActivePower  \
# 0  0.502756   0.068010    0.327608          0.233983     0.000000
# 1  0.488541   0.214106    0.739803          0.378830     0.303371
# 2  0.490281   0.229219    0.507514          0.718663     0.000000
# 3  0.475776   0.246851    0.813225          0.715877     0.467749
# 4  0.507978   0.163728    0.622585          0.428969     0.185185
# 5  0.553235   0.239295    0.841134          0.571031     0.653350
# 6  0.472585   0.362720    0.902963          0.423398     0.980025
# 7  0.522193   0.113350    0.574925          0.718663     0.131502
# 8  0.482158   0.130982    0.518248          0.498607     0.000000
# 9  0.512910   0.118388    0.468441          0.657382     0.066167
#
#    Spinner-Temperature  Log-T-Raw-FrontBearingTemperature  \
# 0             0.413333                           0.264516
# 1             0.480000                           0.341935
# 2             0.466667                           0.290323
# 3             0.666667                           0.406452
# 4             0.586667                           0.400000
# 5             0.626667                           0.387097
# 6             0.720000                           0.412903
# 7             0.680000                           0.451613
# 8             0.440000                           0.290323
# 9             0.666667                           0.393548
#
#    Log-T-Raw-RearBearingTemperature  Log-T-Raw-BladeAPitchHeatSink  \
# 0                          0.266234                       0.411111
# 1                          0.350649                       0.455556
# 2                          0.292208                       0.500000
# 3                          0.389610                       0.544444
# 4                          0.383117                       0.633333
# 5                          0.363636                       0.433333
# 6                          0.370130                       0.500000
# 7                          0.376623                       0.488889
# 8                          0.233766                       0.411111
# 9                          0.363636                       0.611111
#
#    Log-T-Raw-BladeBPitchHeatSink  ...  Log-T-Raw-Rectifier1HeatSink  \
# 0                       0.420455  ...                      0.161290
# 1                       0.477273  ...                      0.602151
# 2                       0.522727  ...                      0.860215
# 3                       0.579545  ...                      0.698925
# 4                       0.659091  ...                      0.623656
# 5                       0.477273  ...                      0.602151
# 6                       0.545455  ...                      0.666667
# 7                       0.522727  ...                      0.602151
# 8                       0.420455  ...                      0.795699
# 9                       0.625000  ...                      0.612903
#
#    Log-T-Raw-Rectifier2HeatSink  Log-T-Raw-RectifierCabinetTemperature  \
# 0                      0.197531                               0.384615
# 1                      0.444444                               0.400000
# 2                      0.925926                               0.538462
# 3                      0.543210                               0.538462
# 4                      0.629630                               0.676923
# 5                      0.481481                               0.384615
# 6                      0.592593                               0.353846
# 7                      0.740741                               0.476923
# 8                      0.901235                               0.446154
# 9                      0.666667                               0.615385
#
#    Log-T-Raw-ExcitationHeatSink  Ambient-Temperature  \
# 0                      0.297872             0.250000
# 1                      0.521277             0.288462
# 2                      0.478723             0.384615
# 3                      0.500000             0.442308
# 4                      0.521277             0.442308
# 5                      0.446809             0.365385
# 6                      0.372340             0.423077
# 7                      0.510638             0.461538
# 8                      0.382979             0.173077
# 9                      0.457447             0.576923
#
#    Log-T-Raw-TowerTemperature  Log-T-Raw-ControlCabinetTemperature  \
# 0                    0.379747                             0.549020
# 1                    0.455696                             0.274510
# 2                    0.481013                             0.294118
# 3                    0.569620                             0.450980
# 4                    0.632911                             0.509804
# 5                    0.544304                             0.392157
# 6                    0.670886                             0.549020
# 7                    0.658228                             0.588235
# 8                    0.341772                             0.313725
# 9                    0.670886                             0.549020
#
#    Log-T-Raw-TransformerTemperature  Average blade angle across A B C  \
# 0                          0.216495                          0.000000
# 1                          0.340206                          0.000000
# 2                          0.298969                          0.176880
# 3                          0.463918                          0.000000
# 4                          0.587629                          0.000000
# 5                          0.463918                          0.001633
# 6                          0.670103                          0.041580
# 7                          0.680412                          0.000000
# 8                          0.195876                          0.077719
# 9                          0.381443                          0.000000
#
#    WindDirection
# 0       0.433491
# 1       0.530625
# 2       0.783461
# 3       0.771087
# 4       0.581563
# 5       0.718911
# 6       0.675191
# 7       0.806146
# 8       0.614766
# 9       0.754176
#
# [10 rows x 34 columns]

# %% [markdown]
# ### SVM method

# %%
svm_method.get_svm_model(X_train_scaled, X_test_scaled, y_train, y_test)

# %% [markdown]
# ### SMOTE (Synthetic Minority Oversampling Technique):

# %%
sm = SMOTE(random_state=12)
X_
