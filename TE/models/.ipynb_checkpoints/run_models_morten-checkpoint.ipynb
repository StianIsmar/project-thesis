# %% [markdown]
# ## Read Undersampled_data:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from zipfile import ZipFile
from sklearn.preprocessing import MinMaxScaler

import nbimporter
import random_forest_method
import performance_measure
import svm_method_lime_compatible
import data_sampling
import split_data_set
import target_parser
import lime_method
# Out:
# Importing Jupyter notebook from random_forest_method.ipynb
# Importing Jupyter notebook from performance_measure.ipynb
# Importing Jupyter notebook from pandas_to_latex.ipynb
# Importing Jupyter notebook from multiscorer.ipynb
# /Users/mortenolsenosvik/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /Users/mortenolsenosvik/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /Users/mortenolsenosvik/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /Users/mortenolsenosvik/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /Users/mortenolsenosvik/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /Users/mortenolsenosvik/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# Importing Jupyter notebook from svm_method_lime_compatible.ipynb
# Importing Jupyter notebook from data_sampling.ipynb
# Importing Jupyter notebook from split_data_set.ipynb
# Importing Jupyter notebook from target_parser.ipynb
# Importing Jupyter notebook from lime_method.ipynb

# %%
path = "../../../undersampled_data.zip"

zip_file = ZipFile(path)
undersampled_data = pd.read_csv(zip_file.open('undersampled_data.csv')) #, nrows=500000)
#data = pd.read_csv(path, compression='zip', sep=',')#, nrows=500000)

# %%
data_sampling.get_statues_percentage(undersampled_data, 'Undersampled dataset to max size 300 000:\n')
data_sampling.plot_balance(undersampled_data, 'Status')
# Out:
# Proportion of failures in Undersampled dataset to max size 300 000:
#
# Status			 Percentage	 Amount
# Other:			 56.269%	 300000
# Status_9_Substatus_8: 	 42.890 %	 228668
# Status_62_Substatus_7:	 0.769%		 4098
# Status_62_Substatus_30:	 0.072%		 383

# %% [markdown]
# ## Do more undersampling

# %%
undersampled_data = data_sampling.undersample_dataset(undersampled_data,20000,"Other")
undersampled_data = data_sampling.undersample_dataset(undersampled_data,20000,"Status_9_Substatus_8")

# %%
data_sampling.get_statues_percentage(undersampled_data, 'Undersampled dataset to max size 20 000:\n')
data_sampling.plot_balance(undersampled_data, 'Status')
# Out:
# Proportion of failures in Undersampled dataset to max size 20 000:
#
# Status			 Percentage	 Amount
# Other:			 44.963%	 20000
# Status_9_Substatus_8: 	 44.963 %	 20000
# Status_62_Substatus_7:	 9.213%		 4098
# Status_62_Substatus_30:	 0.861%		 383

# %%
X = undersampled_data.drop(columns = ['Status', 'TimeStamp'])
y = np.array(undersampled_data.Status)
X.shape
# Out:
# (44481, 34)

# %%
y
# Out:
# array(['Status_9_Substatus_8', 'Other', 'Status_9_Substatus_8', ...,
#        'Status_9_Substatus_8', 'Status_9_Substatus_8',
#        'Status_9_Substatus_8'], dtype=object)

# %% [markdown]
# ### Translate status codes to int for easier comparison

# %%
y = target_parser.status_to_code(y)
y
# Out:
# array([1, 0, 1, ..., 1, 1, 1])

# %% [markdown]
# ### Split into training and test

# %%
X_train, X_test, y_train, y_test = split_data_set.split_data(X,y)

# %%
np.asarray(np.unique(y_train, return_counts=True)).T
# Out:
# array([[    0, 13400],
#        [    1, 13400],
#        [    2,  2746],
#        [    3,   256]])

# %% [markdown]
# # Preprocessing

# %% [markdown]
# ### Feature Extraction (based on lowest feature importance from RF)

# %%
dropColumns = ['Log-T-Raw-BladeATemperature', 'Log-T-Raw-BladeBTemperature', 'Log-T-Raw-BladeCTemperature',
               'Log-T-Raw-BladeAPitchControlBox', 'Log-T-Raw-BladeBPitchControlBox', 'Log-T-Raw-BladeCPitchControlBox',
               'Log-T-Raw-BladeAPitchHeatSink', 'Log-T-Raw-BladeBPitchHeatSink', 'Log-T-Raw-BladeCPitchHeatSink',
               'Log-T-Raw-RectifierCabinetTemperature', 'Log-T-Raw-NacelleControlCabinetTemperature',
               'WindVane', 'WindDirection', 'WindSpeed','Nacelle-Temperature', 'Spinner-Temperature']

def extract_features(X_train, X_test, dropColumns):
    X_train_ex = X_train.drop(columns=dropColumns)
    X_test_ex = X_test.drop(columns=dropColumns)
    return X_train_ex, X_test_ex

# %% [markdown]
# ### MinMaxScaling

# %%
def do_MinMaxScaling(X_train, X_test):
    scaler  = MinMaxScaler()
    X_train_scaled = scaler.fit_transform(X_train)
    X_test_scaled  = scaler.transform(X_test)
    # Convert to DataFrame
    X_train_scaled_df = pd.DataFrame(X_train_scaled, columns = list(X_train))
    X_test_scaled_df  = pd.DataFrame(X_test_scaled, columns = list(X_train))
    
    return X_train_scaled_df, X_test_scaled_df

# %%
X_train_scaled, X_test_scaled = do_MinMaxScaling(X_train, X_test)

# %%
svm = svm_method_lime_compatible.get_svm_model_balanced_with_prob(X_train_scaled, X_test_scaled, y_train, y_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-144739178693> in <module>
# ----> 1 svm = svm_method_lime_compatible.get_svm_model_balanced_with_prob(X_train_scaled, X_test_scaled, y_train, y_test)
#
# AttributeError: module 'svm_method_lime_compatible' has no attribute 'get_svm_model_balanced_with_prob'

# %%
targetNames = svm.classes_
explainer = lime_method.run_lime(X_train_scaled, targetNames)
exp_instance = lime_method.explain_instance(X_test_scaled, svm, explainer, 2, 5)
exp_instance.show_in_notebook(show_table=True) #, show_all=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-7bc5e290802c> in <module>
#       1 targetNames = svm.classes_
#       2 explainer = lime_method.run_lime(X_train_scaled, targetNames)
# ----> 3 exp_instance = lime_method.explain_instance(X_test_scaled, svm, explainer, 2, 5)
#       4 exp_instance.show_in_notebook(show_table=True) #, show_all=True)
#
# ~/Desktop/project-thesis/TE/models/lime_method.ipynb in explain_instance(X_test, model, explainer, instance, numb_features)
#       1 {
#       2  "cells": [
# ----> 3   {
#       4    "cell_type": "code",
#       5    "execution_count": 1,
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py in predict_proba(self)
#     616         datasets.
#     617         """
# --> 618         self._check_proba()
#     619         return self._predict_proba
#     620
#
# ~/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py in _check_proba(self)
#     583     def _check_proba(self):
#     584         if not self.probability:
# --> 585             raise AttributeError("predict_proba is not available when "
#     586                                  " probability=False")
#     587         if self._impl not in ('c_svc', 'nu_svc'):
#
# AttributeError: predict_proba is not available when  probability=False
