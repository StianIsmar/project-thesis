# %%
import pandas as pd

df = pd.read_csv('./DataFromBazefield/bazeFieldFaulsAll.csv')
columns = df.head(0)
df
# Out:
#       TimeStamp;BESS-WTG01-ErrorCode;BESS-WTG02-ErrorCode;BESS-WTG03-ErrorCode;BESS-WTG04-ErrorCode;BESS-WTG05-ErrorCode;BESS-WTG06-ErrorCode;BESS-WTG07-ErrorCode;BESS-WTG08-ErrorCode;BESS-WTG09-ErrorCode;BESS-WTG10-ErrorCode;BESS-WTG11-ErrorCode;BESS-WTG12-ErrorCode;BESS-WTG13-ErrorCode;BESS-WTG14-ErrorCode;BESS-WTG15-ErrorCode;BESS-WTG16-ErrorCode;BESS-WTG17-ErrorCode;BESS-WTG18-ErrorCode;BESS-WTG19-ErrorCode;BESS-WTG20-ErrorCode;BESS-WTG21-ErrorCode;BESS-WTG22-ErrorCode;BESS-WTG23-ErrorCode;BESS-WTG24-ErrorCode;BESS-WTG25-ErrorCode
# 0      02-08-2017 08:07:15.000;2;;;;;;;;;;;;;;;;;;;;;;;;
# 1      02-08-2017 08:07:16.000;1;;;;;;;;;;;;;;;;;;;;;;;;
# 2      02-08-2017 08:10:55.000;0;;;;;;;;;;;;;;;;;;;;;;;;
# 3      03-08-2017 11:28:11.000;2002;;;;;;;;;;;;;;;;;;...
# 4      03-08-2017 11:34:46.000;2;;;;;;;;;;;;;;;;;;;;;;;;
# 5      03-08-2017 11:34:49.000;1;;;;;;;;;;;;;;;;;;;;;;;;
# 6      03-08-2017 11:38:27.000;0;;;;;;;;;;;;;;;;;;;;;;;;
# ...

# %%
df[["TimeStamp", "BESS-WTG01-ErrorCode", "BESS-WTG02-ErrorCode",]] = df["Date"].str.split("/", expand=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2601             try:
# -> 2602                 return self._engine.get_loc(key)
#    2603             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Date'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-f4bd4c4d0b67> in <module>
# ...

# %%
string = "TimeStamp;BESS-WTG01-ErrorCode;BESS-WTG02-ErrorCode;BESS-WTG03-ErrorCode;BESS-WTG04-ErrorCode;BESS-WTG05-ErrorCode;BESS-WTG06-ErrorCode;BESS-WTG07-ErrorCode;BESS-WTG08-ErrorCode;BESS-WTG09-ErrorCode;BESS-WTG10-ErrorCode;BESS-WTG11-ErrorCode;BESS-WTG12-ErrorCode;BESS-WTG13-ErrorCode;BESS-WTG14-ErrorCode;BESS-WTG15-ErrorCode;BESS-WTG16-ErrorCode;BESS-WTG17-ErrorCode;BESS-WTG18-ErrorCode;BESS-WTG19-ErrorCode;BESS-WTG20-ErrorCode;BESS-WTG21-ErrorCode;BESS-WTG22-ErrorCode;BESS-WTG23-ErrorCode;BESS-WTG24-ErrorCode;BESS-WTG25-ErrorCode"
string = string.split(';')
string
# Out:
# ['TimeStamp',
#  'BESS-WTG01-ErrorCode',
#  'BESS-WTG02-ErrorCode',
#  'BESS-WTG03-ErrorCode',
#  'BESS-WTG04-ErrorCode',
#  'BESS-WTG05-ErrorCode',
#  'BESS-WTG06-ErrorCode',
#  'BESS-WTG07-ErrorCode',
#  'BESS-WTG08-ErrorCode',
#  'BESS-WTG09-ErrorCode',
#  'BESS-WTG10-ErrorCode',
#  'BESS-WTG11-ErrorCode',
#  'BESS-WTG12-ErrorCode',
#  'BESS-WTG13-ErrorCode',
#  'BESS-WTG14-ErrorCode',
#  'BESS-WTG15-ErrorCode',
#  'BESS-WTG16-ErrorCode',
#  'BESS-WTG17-ErrorCode',
#  'BESS-WTG18-ErrorCode',
#  'BESS-WTG19-ErrorCode',
#  'BESS-WTG20-ErrorCode',
#  'BESS-WTG21-ErrorCode',
#  'BESS-WTG22-ErrorCode',
#  'BESS-WTG23-ErrorCode',
#  'BESS-WTG24-ErrorCode',
#  'BESS-WTG25-ErrorCode']

# %%
df[['TimeStamp',
 'BESS-WTG01-ErrorCode',
 'BESS-WTG02-ErrorCode',
 'BESS-WTG03-ErrorCode',
 'BESS-WTG04-ErrorCode',
 'BESS-WTG05-ErrorCode',
 'BESS-WTG06-ErrorCode',
 'BESS-WTG07-ErrorCode',
 'BESS-WTG08-ErrorCode',
 'BESS-WTG09-ErrorCode',
 'BESS-WTG10-ErrorCode',
 'BESS-WTG11-ErrorCode',
 'BESS-WTG12-ErrorCode',
 'BESS-WTG13-ErrorCode',
 'BESS-WTG14-ErrorCode',
 'BESS-WTG15-ErrorCode',
 'BESS-WTG16-ErrorCode',
 'BESS-WTG17-ErrorCode',
 'BESS-WTG18-ErrorCode',
 'BESS-WTG19-ErrorCode',
 'BESS-WTG20-ErrorCode',
 'BESS-WTG21-ErrorCode',
 'BESS-WTG22-ErrorCode',
 'BESS-WTG23-ErrorCode',
 'BESS-WTG24-ErrorCode',
 'BESS-WTG25-ErrorCode']] = df["TimeStamp;BESS-WTG01-ErrorCode;BESS-WTG02-ErrorCode;BESS-WTG03-ErrorCode;BESS-WTG04-ErrorCode;BESS-WTG05-ErrorCode;BESS-WTG06-ErrorCode;BESS-WTG07-ErrorCode;BESS-WTG08-ErrorCode;BESS-WTG09-ErrorCode;BESS-WTG10-ErrorCode;BESS-WTG11-ErrorCode;BESS-WTG12-ErrorCode;BESS-WTG13-ErrorCode;BESS-WTG14-ErrorCode;BESS-WTG15-ErrorCode;BESS-WTG16-ErrorCode;BESS-WTG17-ErrorCode;BESS-WTG18-ErrorCode;BESS-WTG19-ErrorCode;BESS-WTG20-ErrorCode;BESS-WTG21-ErrorCode;BESS-WTG22-ErrorCode;BESS-WTG23-ErrorCode;BESS-WTG24-ErrorCode;BESS-WTG25-ErrorCode"].str.split(";",expand=True)
df
# Out:
#       TimeStamp;BESS-WTG01-ErrorCode;BESS-WTG02-ErrorCode;BESS-WTG03-ErrorCode;BESS-WTG04-ErrorCode;BESS-WTG05-ErrorCode;BESS-WTG06-ErrorCode;BESS-WTG07-ErrorCode;BESS-WTG08-ErrorCode;BESS-WTG09-ErrorCode;BESS-WTG10-ErrorCode;BESS-WTG11-ErrorCode;BESS-WTG12-ErrorCode;BESS-WTG13-ErrorCode;BESS-WTG14-ErrorCode;BESS-WTG15-ErrorCode;BESS-WTG16-ErrorCode;BESS-WTG17-ErrorCode;BESS-WTG18-ErrorCode;BESS-WTG19-ErrorCode;BESS-WTG20-ErrorCode;BESS-WTG21-ErrorCode;BESS-WTG22-ErrorCode;BESS-WTG23-ErrorCode;BESS-WTG24-ErrorCode;BESS-WTG25-ErrorCode  \
# 0      02-08-2017 08:07:15.000;2;;;;;;;;;;;;;;;;;;;;;;;;
# 1      02-08-2017 08:07:16.000;1;;;;;;;;;;;;;;;;;;;;;;;;
# 2      02-08-2017 08:10:55.000;0;;;;;;;;;;;;;;;;;;;;;;;;
# 3      03-08-2017 11:28:11.000;2002;;;;;;;;;;;;;;;;;;...
# 4      03-08-2017 11:34:46.000;2;;;;;;;;;;;;;;;;;;;;;;;;
# 5      03-08-2017 11:34:49.000;1;;;;;;;;;;;;;;;;;;;;;;;;
# 6      03-08-2017 11:38:27.000;0;;;;;;;;;;;;;;;;;;;;;;;;
# ...

# %%
del df['TimeStamp;BESS-WTG01-ErrorCode;BESS-WTG02-ErrorCode;BESS-WTG03-ErrorCode;BESS-WTG04-ErrorCode;BESS-WTG05-ErrorCode;BESS-WTG06-ErrorCode;BESS-WTG07-ErrorCode;BESS-WTG08-ErrorCode;BESS-WTG09-ErrorCode;BESS-WTG10-ErrorCode;BESS-WTG11-ErrorCode;BESS-WTG12-ErrorCode;BESS-WTG13-ErrorCode;BESS-WTG14-ErrorCode;BESS-WTG15-ErrorCode;BESS-WTG16-ErrorCode;BESS-WTG17-ErrorCode;BESS-WTG18-ErrorCode;BESS-WTG19-ErrorCode;BESS-WTG20-ErrorCode;BESS-WTG21-ErrorCode;BESS-WTG22-ErrorCode;BESS-WTG23-ErrorCode;BESS-WTG24-ErrorCode;BESS-WTG25-ErrorCode']

# %%
df
# Out:
#                      TimeStamp BESS-WTG01-ErrorCode BESS-WTG02-ErrorCode  \
# 0      02-08-2017 08:07:15.000                    2
# 1      02-08-2017 08:07:16.000                    1
# 2      02-08-2017 08:10:55.000                    0
# 3      03-08-2017 11:28:11.000                 2002
# 4      03-08-2017 11:34:46.000                    2
# 5      03-08-2017 11:34:49.000                    1
# 6      03-08-2017 11:38:27.000                    0
# 7      05-08-2017 00:03:03.000                    0
# 8      05-08-2017 00:03:04.000                    0
# 9      05-08-2017 00:03:09.000                    0
# 10     05-08-2017 00:03:11.000                    0
# 11     06-08-2017 09:53:28.000                 2001
# 12     06-08-2017 10:18:04.001                    1
# 13     06-08-2017 10:21:42.000                    0
# 14     07-08-2017 00:31:44.000                 2001
# 15     07-08-2017 01:43:39.000                    2
# 16     07-08-2017 01:43:41.000                    1
# ...

# %%
df.to_csv("file_name1", sep='\t')
