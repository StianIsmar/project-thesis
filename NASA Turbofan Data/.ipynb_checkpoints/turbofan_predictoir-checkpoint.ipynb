# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier

# %%
data = np.loadtxt('train_FD001.txt', skiprows=0, unpack=False)

data_pd = pd.DataFrame(data, columns=['Unit#','time','op1','op2','op3','s1','s2','s3','s4','s5',
                                      's6','s7','s8','s9','s10','s11','s12','s13','s14','s15',
                                      's16','s17','s18','s19','s20','s21'])
X = data_pd.drop(['time'], axis=1)
Y = pd.DataFrame()
time = np.array([])
for i in range(100):
    engine = (data_pd.loc[data_pd['Unit#'] == i+1])
    time = np.append(time, np.flip(np.array(engine['time'])))
time
Y = pd.DataFrame(time, columns=['time'])
Y
# Out:
#         time
# 0      192.0
# 1      191.0
# 2      190.0
# 3      189.0
# 4      188.0
# 5      187.0
# 6      186.0
# 7      185.0
# 8      184.0
# 9      183.0
# 10     182.0
# 11     181.0
# 12     180.0
# 13     179.0
# 14     178.0
# 15     177.0
# 16     176.0
# 17     175.0
# 18     174.0
# 19     173.0
# 20     172.0
# 21     171.0
# 22     170.0
# 23     169.0
# 24     168.0
# 25     167.0
# 26     166.0
# 27     165.0
# 28     164.0
# 29     163.0
# ...      ...
# 20601   30.0
# 20602   29.0
# 20603   28.0
# 20604   27.0
# 20605   26.0
# 20606   25.0
# 20607   24.0
# 20608   23.0
# 20609   22.0
# 20610   21.0
# 20611   20.0
# 20612   19.0
# 20613   18.0
# 20614   17.0
# 20615   16.0
# 20616   15.0
# 20617   14.0
# 20618   13.0
# 20619   12.0
# 20620   11.0
# 20621   10.0
# 20622    9.0
# 20623    8.0
# 20624    7.0
# 20625    6.0
# 20626    5.0
# 20627    4.0
# 20628    3.0
# 20629    2.0
# 20630    1.0
#
# [20631 rows x 1 columns]

# %%
X_test = pd.read_csv('test_FD001.txt')
X_test.shape
# Out:
# (13095, 1)

# %%
# Plot of what the data sets test_x and test_y actually look like

def plot_data(x_data, y_data, engine_number, feature):
    
    fig = plt.figure(figsize=(12, 8))
    ax = fig.add_subplot(111)
    ax.plot(x_data, y_data, color='b', marker='.')
    plt.title('Data from engine: {}'.format(engine_number), fontsize=20)
    plt.xlabel('Time', fontsize=16)
    plt.ylabel('Feature {}'.format(feature), fontsize=16)
    plt.legend(fontsize=14)
    plt.grid(True)
#    ax.set_ylim(np.amin(y_data), np.amax(y_data))
    print(np.amax(y_data))
    print(np.amin(y_data))
    plt.show()

# %%
for i in range(21):
    engine_number = 3
    engine = data_pd.loc[data_pd['Unit#'] == engine_number]
    feature = 's{}'.format(i+1)
    plot_data(engine['time'], engine[feature], engine_number, feature)
# Out:
# 518.67
# 518.67
# 643.93
# 641.48
# 1606.5
# 1577.22
# 1438.51
# 1389.86
# 14.62
# 14.62
# 21.61
# 21.6
# 555.28
# 551.31
# 2388.19
# 2387.94
# 9197.52
# 9047.08
# 1.3
# 1.3
# 48.38
# 46.94
# 523.18
# 519.53
# 2388.2
# 2387.95
# 8255.34
# 8130.42
# 8.5363
# 8.3682
# 0.03
# 0.03
# 399.0
# 390.0
# 2388.0
# 2388.0
# 100.0
# 100.0
# 39.23
# 38.37
# 23.5181
# 22.9562

# %%
engine = data_pd.loc[data_pd['Unit#'] == 1]
engine.plot(x='time', y='op3', kind='scatter')
