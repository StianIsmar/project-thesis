# %%
import pandas as pd
from pandas import ExcelWriter
from pandas import ExcelFile
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
# loading the alarm data
df = pd.read_excel('./DataFromBazefield/onlyAlarmsBessaker.xlsx')
df
# Out:
#            Site     Turbine                    Alarm       Code Event Type  \
# 0      Bessaker  BESS-WTG21    Status_62_Substatus_7       62:7          A
# 1      Bessaker  BESS-WTG21    Status_62_Substatus_7       62:7          A
# 2      Bessaker  BESS-WTG12   Status_222_Substatus_3      222:3          A
# 3      Bessaker  BESS-WTG12  Status_228_Substatus_90     228:90          A
# 4      Bessaker  BESS-WTG25     Status_8_Substatus_0   0.333333          A
# 5      Bessaker  BESS-WTG20     Status_2_Substatus_1  0.0840278          A
# 6      Bessaker  BESS-WTG18     Status_2_Substatus_1  0.0840278          A
# 7      Bessaker  BESS-WTG16     Status_2_Substatus_1  0.0840278          A
# 8      Bessaker  BESS-WTG20     Status_2_Substatus_1  0.0840278          A
# 9      Bessaker  BESS-WTG19     Status_2_Substatus_1  0.0840278          A
# 10     Bessaker  BESS-WTG18     Status_2_Substatus_1  0.0840278          A
# ...

# %%
desc = df.groupby('Description').size().sort_values(ascending=False)

# Printing the counted alarms
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(desc)
# Out:
# Description
# N   2:1 Lack of wind - (Wind speed too low)                                        10700
# N  8:0 Maintenance - (Maintenance)                                                  1772
# N   21:2 Cable twisted - (Right (2-3 turns))                                         710
# N   9:8 Generator heating - (Manual)                                                 459
# R  60:15 Mains failure - (Overvoltage L2)                                            440
# R  240:0 STATUS: Remote control PC (switched on)                                     430
# R  62:7 Feeding fault - (Diff. P-set/P-actual)                                       424
# N   1:1 Turbine Stopped - (Control cabinet)                                          363
# N   17:0 Test safety system - (Test safety system)                                   338
# R  240:246 STATUS: Remote control PC (Timeout receivebuffer)                         333
# ...

# %%
desc.shape
# Out:
# (256,)

# %%
mostFrequentAlarms = desc.head(15)
# mostFrequentAlarms = copy.drop(copy.head(n).index,inplace=True) # drop first n rows

plt.title('Most common alarms from SCADA')

# Removing the too little wind alarm and the alarm concering maintenance:
mostFrequentAlarms = mostFrequentAlarms.iloc[2:]

mostFrequentAlarms.plot.bar()
